# %%
import os
import shutil

# Ruta donde se encuentran todos los archivos
source_dir = './Dataset_500_EMPRESAS'  # Cambia esto si es necesario

# Obtener todos los archivos en el directorio
files = os.listdir(source_dir)

# Crear un conjunto de todos los tickers únicos
tickers = set()
for file in files:
    if file.endswith('.csv') or file.endswith('.json'):
        parts = file.split('_')
        if len(parts) >= 2:
            ticker = parts[0]
            tickers.add(ticker)

# Crear carpetas y mover archivos
for ticker in tickers:
    folder_path = os.path.join(source_dir, ticker)
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
    
    for file in files:
        if file.startswith(ticker + '_'):
            source_file = os.path.join(source_dir, file)
            dest_file = os.path.join(folder_path, file)
            shutil.move(source_file, dest_file)
            print(f"Moved {file} to {folder_path}")

print("Organización completada.")
# Out:
# Moved NFLX_cash_flow.csv to ./Dataset_500_EMPRESAS/NFLX
# Moved NFLX_balance_sheet.csv to ./Dataset_500_EMPRESAS/NFLX
# Moved NFLX_info.json to ./Dataset_500_EMPRESAS/NFLX
# Moved NFLX_income_statement.csv to ./Dataset_500_EMPRESAS/NFLX
# Moved NFLX_historico.csv to ./Dataset_500_EMPRESAS/NFLX
# Moved GOOGL_cash_flow.csv to ./Dataset_500_EMPRESAS/GOOGL
# Moved GOOGL_income_statement.csv to ./Dataset_500_EMPRESAS/GOOGL
# Moved GOOGL_info.json to ./Dataset_500_EMPRESAS/GOOGL
# Moved GOOGL_balance_sheet.csv to ./Dataset_500_EMPRESAS/GOOGL
# Moved GOOGL_historico.csv to ./Dataset_500_EMPRESAS/GOOGL
# Moved DIS_historico.csv to ./Dataset_500_EMPRESAS/DIS
# Moved DIS_cash_flow.csv to ./Dataset_500_EMPRESAS/DIS
# Moved DIS_income_statement.csv to ./Dataset_500_EMPRESAS/DIS
# Moved DIS_info.json to ./Dataset_500_EMPRESAS/DIS
# Moved DIS_balance_sheet.csv to ./Dataset_500_EMPRESAS/DIS
# Moved IQV_cash_flow.csv to ./Dataset_500_EMPRESAS/IQV
# Moved IQV_balance_sheet.csv to ./Dataset_500_EMPRESAS/IQV
# Moved IQV_info.json to ./Dataset_500_EMPRESAS/IQV
# Moved IQV_income_statement.csv to ./Dataset_500_EMPRESAS/IQV
# Moved IQV_historico.csv to ./Dataset_500_EMPRESAS/IQV
# Moved ROK_info.json to ./Dataset_500_EMPRESAS/ROK
# Moved ROK_cash_flow.csv to ./Dataset_500_EMPRESAS/ROK
# Moved ROK_historico.csv to ./Dataset_500_EMPRESAS/ROK
# Moved ROK_income_statement.csv to ./Dataset_500_EMPRESAS/ROK
# Moved ROK_balance_sheet.csv to ./Dataset_500_EMPRESAS/ROK
# Moved TJX_info.json to ./Dataset_500_EMPRESAS/TJX
# Moved TJX_balance_sheet.csv to ./Dataset_500_EMPRESAS/TJX
# Moved TJX_historico.csv to ./Dataset_500_EMPRESAS/TJX
# Moved TJX_cash_flow.csv to ./Dataset_500_EMPRESAS/TJX
# Moved TJX_income_statement.csv to ./Dataset_500_EMPRESAS/TJX
# Moved GDDY_historico.csv to ./Dataset_500_EMPRESAS/GDDY
# Moved GDDY_info.json to ./Dataset_500_EMPRESAS/GDDY
# Moved GDDY_income_statement.csv to ./Dataset_500_EMPRESAS/GDDY
# Moved GDDY_cash_flow.csv to ./Dataset_500_EMPRESAS/GDDY
# Moved GDDY_balance_sheet.csv to ./Dataset_500_EMPRESAS/GDDY
# Moved MMC_cash_flow.csv to ./Dataset_500_EMPRESAS/MMC
# Moved MMC_info.json to ./Dataset_500_EMPRESAS/MMC
# Moved MMC_balance_sheet.csv to ./Dataset_500_EMPRESAS/MMC
# Moved MMC_historico.csv to ./Dataset_500_EMPRESAS/MMC
# Moved MMC_income_statement.csv to ./Dataset_500_EMPRESAS/MMC
# Moved BSX_info.json to ./Dataset_500_EMPRESAS/BSX
# Moved BSX_historico.csv to ./Dataset_500_EMPRESAS/BSX
# Moved BSX_income_statement.csv to ./Dataset_500_EMPRESAS/BSX
# Moved BSX_balance_sheet.csv to ./Dataset_500_EMPRESAS/BSX
# Moved BSX_cash_flow.csv to ./Dataset_500_EMPRESAS/BSX
# Moved T_cash_flow.csv to ./Dataset_500_EMPRESAS/T
# Moved T_income_statement.csv to ./Dataset_500_EMPRESAS/T
# Moved T_balance_sheet.csv to ./Dataset_500_EMPRESAS/T
# Moved T_info.json to ./Dataset_500_EMPRESAS/T
# Moved T_historico.csv to ./Dataset_500_EMPRESAS/T
# Moved KR_income_statement.csv to ./Dataset_500_EMPRESAS/KR
# Moved KR_historico.csv to ./Dataset_500_EMPRESAS/KR
# Moved KR_info.json to ./Dataset_500_EMPRESAS/KR
# Moved KR_balance_sheet.csv to ./Dataset_500_EMPRESAS/KR
# Moved KR_cash_flow.csv to ./Dataset_500_EMPRESAS/KR
# Moved IR_balance_sheet.csv to ./Dataset_500_EMPRESAS/IR
# Moved IR_income_statement.csv to ./Dataset_500_EMPRESAS/IR
# Moved IR_historico.csv to ./Dataset_500_EMPRESAS/IR
# Moved IR_cash_flow.csv to ./Dataset_500_EMPRESAS/IR
# Moved IR_info.json to ./Dataset_500_EMPRESAS/IR
# Moved PSX_balance_sheet.csv to ./Dataset_500_EMPRESAS/PSX
# Moved PSX_historico.csv to ./Dataset_500_EMPRESAS/PSX
# Moved PSX_income_statement.csv to ./Dataset_500_EMPRESAS/PSX
# Moved PSX_cash_flow.csv to ./Dataset_500_EMPRESAS/PSX
# Moved PSX_info.json to ./Dataset_500_EMPRESAS/PSX
# Moved AZO_historico.csv to ./Dataset_500_EMPRESAS/AZO
# Moved AZO_balance_sheet.csv to ./Dataset_500_EMPRESAS/AZO
# Moved AZO_income_statement.csv to ./Dataset_500_EMPRESAS/AZO
# Moved AZO_info.json to ./Dataset_500_EMPRESAS/AZO
# Moved AZO_cash_flow.csv to ./Dataset_500_EMPRESAS/AZO
# Moved HLT_cash_flow.csv to ./Dataset_500_EMPRESAS/HLT
# Moved HLT_balance_sheet.csv to ./Dataset_500_EMPRESAS/HLT
# Moved HLT_info.json to ./Dataset_500_EMPRESAS/HLT
# Moved HLT_historico.csv to ./Dataset_500_EMPRESAS/HLT
# Moved HLT_income_statement.csv to ./Dataset_500_EMPRESAS/HLT
# Moved DE_cash_flow.csv to ./Dataset_500_EMPRESAS/DE
# Moved DE_income_statement.csv to ./Dataset_500_EMPRESAS/DE
# Moved DE_info.json to ./Dataset_500_EMPRESAS/DE
# Moved DE_historico.csv to ./Dataset_500_EMPRESAS/DE
# Moved DE_balance_sheet.csv to ./Dataset_500_EMPRESAS/DE
# Moved DVN_historico.csv to ./Dataset_500_EMPRESAS/DVN
# Moved DVN_income_statement.csv to ./Dataset_500_EMPRESAS/DVN
# Moved DVN_info.json to ./Dataset_500_EMPRESAS/DVN
# Moved DVN_cash_flow.csv to ./Dataset_500_EMPRESAS/DVN
# Moved DVN_balance_sheet.csv to ./Dataset_500_EMPRESAS/DVN
# Moved MOH_historico.csv to ./Dataset_500_EMPRESAS/MOH
# Moved MOH_income_statement.csv to ./Dataset_500_EMPRESAS/MOH
# Moved MOH_cash_flow.csv to ./Dataset_500_EMPRESAS/MOH
# Moved MOH_balance_sheet.csv to ./Dataset_500_EMPRESAS/MOH
# Moved MOH_info.json to ./Dataset_500_EMPRESAS/MOH
# Moved INTC_cash_flow.csv to ./Dataset_500_EMPRESAS/INTC
# Moved INTC_balance_sheet.csv to ./Dataset_500_EMPRESAS/INTC
# Moved INTC_income_statement.csv to ./Dataset_500_EMPRESAS/INTC
# Moved INTC_info.json to ./Dataset_500_EMPRESAS/INTC
# Moved INTC_historico.csv to ./Dataset_500_EMPRESAS/INTC
# Moved TYL_info.json to ./Dataset_500_EMPRESAS/TYL
# Moved TYL_balance_sheet.csv to ./Dataset_500_EMPRESAS/TYL
# Moved TYL_historico.csv to ./Dataset_500_EMPRESAS/TYL
# Moved TYL_cash_flow.csv to ./Dataset_500_EMPRESAS/TYL
# Moved TYL_income_statement.csv to ./Dataset_500_EMPRESAS/TYL
# Moved MCO_info.json to ./Dataset_500_EMPRESAS/MCO
# Moved MCO_historico.csv to ./Dataset_500_EMPRESAS/MCO
# Moved MCO_income_statement.csv to ./Dataset_500_EMPRESAS/MCO
# Moved MCO_balance_sheet.csv to ./Dataset_500_EMPRESAS/MCO
# Moved MCO_cash_flow.csv to ./Dataset_500_EMPRESAS/MCO
# Moved CPAY_historico.csv to ./Dataset_500_EMPRESAS/CPAY
# Moved CPAY_info.json to ./Dataset_500_EMPRESAS/CPAY
# Moved CPAY_balance_sheet.csv to ./Dataset_500_EMPRESAS/CPAY
# Moved CPAY_cash_flow.csv to ./Dataset_500_EMPRESAS/CPAY
# Moved CPAY_income_statement.csv to ./Dataset_500_EMPRESAS/CPAY
# Moved MAR_cash_flow.csv to ./Dataset_500_EMPRESAS/MAR
# Moved MAR_info.json to ./Dataset_500_EMPRESAS/MAR
# Moved MAR_income_statement.csv to ./Dataset_500_EMPRESAS/MAR
# Moved MAR_balance_sheet.csv to ./Dataset_500_EMPRESAS/MAR
# Moved MAR_historico.csv to ./Dataset_500_EMPRESAS/MAR
# Moved WDAY_historico.csv to ./Dataset_500_EMPRESAS/WDAY
# Moved WDAY_balance_sheet.csv to ./Dataset_500_EMPRESAS/WDAY
# Moved WDAY_info.json to ./Dataset_500_EMPRESAS/WDAY
# Moved WDAY_cash_flow.csv to ./Dataset_500_EMPRESAS/WDAY
# Moved WDAY_income_statement.csv to ./Dataset_500_EMPRESAS/WDAY
# Moved DFS_income_statement.csv to ./Dataset_500_EMPRESAS/DFS
# Moved DFS_balance_sheet.csv to ./Dataset_500_EMPRESAS/DFS
# Moved DFS_historico.csv to ./Dataset_500_EMPRESAS/DFS
# Moved DFS_cash_flow.csv to ./Dataset_500_EMPRESAS/DFS
# Moved DFS_info.json to ./Dataset_500_EMPRESAS/DFS
# Moved META_income_statement.csv to ./Dataset_500_EMPRESAS/META
# Moved META_balance_sheet.csv to ./Dataset_500_EMPRESAS/META
# Moved META_cash_flow.csv to ./Dataset_500_EMPRESAS/META
# Moved META_info.json to ./Dataset_500_EMPRESAS/META
# Moved META_historico.csv to ./Dataset_500_EMPRESAS/META
# Moved TDG_historico.csv to ./Dataset_500_EMPRESAS/TDG
# Moved TDG_balance_sheet.csv to ./Dataset_500_EMPRESAS/TDG
# Moved TDG_income_statement.csv to ./Dataset_500_EMPRESAS/TDG
# Moved TDG_cash_flow.csv to ./Dataset_500_EMPRESAS/TDG
# Moved TDG_info.json to ./Dataset_500_EMPRESAS/TDG
# Moved VMC_info.json to ./Dataset_500_EMPRESAS/VMC
# Moved VMC_cash_flow.csv to ./Dataset_500_EMPRESAS/VMC
# Moved VMC_income_statement.csv to ./Dataset_500_EMPRESAS/VMC
# Moved VMC_historico.csv to ./Dataset_500_EMPRESAS/VMC
# Moved VMC_balance_sheet.csv to ./Dataset_500_EMPRESAS/VMC
# Moved PM_balance_sheet.csv to ./Dataset_500_EMPRESAS/PM
# Moved PM_income_statement.csv to ./Dataset_500_EMPRESAS/PM
# Moved PM_cash_flow.csv to ./Dataset_500_EMPRESAS/PM
# Moved PM_historico.csv to ./Dataset_500_EMPRESAS/PM
# Moved PM_info.json to ./Dataset_500_EMPRESAS/PM
# Moved MET_income_statement.csv to ./Dataset_500_EMPRESAS/MET
# Moved MET_balance_sheet.csv to ./Dataset_500_EMPRESAS/MET
# Moved MET_info.json to ./Dataset_500_EMPRESAS/MET
# Moved MET_historico.csv to ./Dataset_500_EMPRESAS/MET
# Moved MET_cash_flow.csv to ./Dataset_500_EMPRESAS/MET
# Moved CNC_income_statement.csv to ./Dataset_500_EMPRESAS/CNC
# Moved CNC_cash_flow.csv to ./Dataset_500_EMPRESAS/CNC
# Moved CNC_info.json to ./Dataset_500_EMPRESAS/CNC
# Moved CNC_historico.csv to ./Dataset_500_EMPRESAS/CNC
# Moved CNC_balance_sheet.csv to ./Dataset_500_EMPRESAS/CNC
# Moved STT_balance_sheet.csv to ./Dataset_500_EMPRESAS/STT
# Moved STT_historico.csv to ./Dataset_500_EMPRESAS/STT
# Moved STT_cash_flow.csv to ./Dataset_500_EMPRESAS/STT
# Moved STT_income_statement.csv to ./Dataset_500_EMPRESAS/STT
# Moved STT_info.json to ./Dataset_500_EMPRESAS/STT
# Moved MSFT_cash_flow.csv to ./Dataset_500_EMPRESAS/MSFT
# Moved MSFT_income_statement.csv to ./Dataset_500_EMPRESAS/MSFT
# Moved MSFT_balance_sheet.csv to ./Dataset_500_EMPRESAS/MSFT
# Moved MSFT_info.json to ./Dataset_500_EMPRESAS/MSFT
# Moved MSFT_historico.csv to ./Dataset_500_EMPRESAS/MSFT
# Moved KEY_historico.csv to ./Dataset_500_EMPRESAS/KEY
# Moved KEY_info.json to ./Dataset_500_EMPRESAS/KEY
# Moved KEY_cash_flow.csv to ./Dataset_500_EMPRESAS/KEY
# Moved KEY_income_statement.csv to ./Dataset_500_EMPRESAS/KEY
# Moved KEY_balance_sheet.csv to ./Dataset_500_EMPRESAS/KEY
# Moved TSN_cash_flow.csv to ./Dataset_500_EMPRESAS/TSN
# Moved TSN_income_statement.csv to ./Dataset_500_EMPRESAS/TSN
# Moved TSN_balance_sheet.csv to ./Dataset_500_EMPRESAS/TSN
# Moved TSN_historico.csv to ./Dataset_500_EMPRESAS/TSN
# Moved TSN_info.json to ./Dataset_500_EMPRESAS/TSN
# Moved CARR_income_statement.csv to ./Dataset_500_EMPRESAS/CARR
# Moved CARR_cash_flow.csv to ./Dataset_500_EMPRESAS/CARR
# Moved CARR_balance_sheet.csv to ./Dataset_500_EMPRESAS/CARR
# Moved CARR_historico.csv to ./Dataset_500_EMPRESAS/CARR
# Moved CARR_info.json to ./Dataset_500_EMPRESAS/CARR
# Moved CMCSA_balance_sheet.csv to ./Dataset_500_EMPRESAS/CMCSA
# Moved CMCSA_historico.csv to ./Dataset_500_EMPRESAS/CMCSA
# Moved CMCSA_cash_flow.csv to ./Dataset_500_EMPRESAS/CMCSA
# Moved CMCSA_income_statement.csv to ./Dataset_500_EMPRESAS/CMCSA
# Moved CMCSA_info.json to ./Dataset_500_EMPRESAS/CMCSA
# Moved JNJ_info.json to ./Dataset_500_EMPRESAS/JNJ
# Moved JNJ_balance_sheet.csv to ./Dataset_500_EMPRESAS/JNJ
# Moved JNJ_cash_flow.csv to ./Dataset_500_EMPRESAS/JNJ
# Moved JNJ_historico.csv to ./Dataset_500_EMPRESAS/JNJ
# Moved JNJ_income_statement.csv to ./Dataset_500_EMPRESAS/JNJ
# Moved TXN_info.json to ./Dataset_500_EMPRESAS/TXN
# Moved TXN_cash_flow.csv to ./Dataset_500_EMPRESAS/TXN
# Moved TXN_historico.csv to ./Dataset_500_EMPRESAS/TXN
# Moved TXN_income_statement.csv to ./Dataset_500_EMPRESAS/TXN
# Moved TXN_balance_sheet.csv to ./Dataset_500_EMPRESAS/TXN
# Moved EMR_cash_flow.csv to ./Dataset_500_EMPRESAS/EMR
# Moved EMR_balance_sheet.csv to ./Dataset_500_EMPRESAS/EMR
# Moved EMR_historico.csv to ./Dataset_500_EMPRESAS/EMR
# Moved EMR_info.json to ./Dataset_500_EMPRESAS/EMR
# Moved EMR_income_statement.csv to ./Dataset_500_EMPRESAS/EMR
# Moved MRNA_income_statement.csv to ./Dataset_500_EMPRESAS/MRNA
# Moved MRNA_info.json to ./Dataset_500_EMPRESAS/MRNA
# Moved MRNA_balance_sheet.csv to ./Dataset_500_EMPRESAS/MRNA
# Moved MRNA_cash_flow.csv to ./Dataset_500_EMPRESAS/MRNA
# Moved MRNA_historico.csv to ./Dataset_500_EMPRESAS/MRNA
# Moved NUE_info.json to ./Dataset_500_EMPRESAS/NUE
# Moved NUE_balance_sheet.csv to ./Dataset_500_EMPRESAS/NUE
# Moved NUE_historico.csv to ./Dataset_500_EMPRESAS/NUE
# Moved NUE_income_statement.csv to ./Dataset_500_EMPRESAS/NUE
# Moved NUE_cash_flow.csv to ./Dataset_500_EMPRESAS/NUE
# Moved ELV_cash_flow.csv to ./Dataset_500_EMPRESAS/ELV
# Moved ELV_income_statement.csv to ./Dataset_500_EMPRESAS/ELV
# Moved ELV_info.json to ./Dataset_500_EMPRESAS/ELV
# Moved ELV_balance_sheet.csv to ./Dataset_500_EMPRESAS/ELV
# Moved ELV_historico.csv to ./Dataset_500_EMPRESAS/ELV
# Moved GL_cash_flow.csv to ./Dataset_500_EMPRESAS/GL
# Moved GL_info.json to ./Dataset_500_EMPRESAS/GL
# Moved GL_balance_sheet.csv to ./Dataset_500_EMPRESAS/GL
# Moved GL_income_statement.csv to ./Dataset_500_EMPRESAS/GL
# Moved GL_historico.csv to ./Dataset_500_EMPRESAS/GL
# Moved WAB_historico.csv to ./Dataset_500_EMPRESAS/WAB
# Moved WAB_balance_sheet.csv to ./Dataset_500_EMPRESAS/WAB
# Moved WAB_income_statement.csv to ./Dataset_500_EMPRESAS/WAB
# Moved WAB_info.json to ./Dataset_500_EMPRESAS/WAB
# Moved WAB_cash_flow.csv to ./Dataset_500_EMPRESAS/WAB
# Moved SBUX_income_statement.csv to ./Dataset_500_EMPRESAS/SBUX
# Moved SBUX_info.json to ./Dataset_500_EMPRESAS/SBUX
# Moved SBUX_historico.csv to ./Dataset_500_EMPRESAS/SBUX
# Moved SBUX_cash_flow.csv to ./Dataset_500_EMPRESAS/SBUX
# Moved SBUX_balance_sheet.csv to ./Dataset_500_EMPRESAS/SBUX
# Moved J_income_statement.csv to ./Dataset_500_EMPRESAS/J
# Moved J_balance_sheet.csv to ./Dataset_500_EMPRESAS/J
# Moved J_historico.csv to ./Dataset_500_EMPRESAS/J
# Moved J_info.json to ./Dataset_500_EMPRESAS/J
# Moved J_cash_flow.csv to ./Dataset_500_EMPRESAS/J
# Moved FDS_cash_flow.csv to ./Dataset_500_EMPRESAS/FDS
# Moved FDS_info.json to ./Dataset_500_EMPRESAS/FDS
# Moved FDS_income_statement.csv to ./Dataset_500_EMPRESAS/FDS
# Moved FDS_balance_sheet.csv to ./Dataset_500_EMPRESAS/FDS
# Moved FDS_historico.csv to ./Dataset_500_EMPRESAS/FDS
# Moved PEP_info.json to ./Dataset_500_EMPRESAS/PEP
# Moved PEP_historico.csv to ./Dataset_500_EMPRESAS/PEP
# Moved PEP_balance_sheet.csv to ./Dataset_500_EMPRESAS/PEP
# Moved PEP_cash_flow.csv to ./Dataset_500_EMPRESAS/PEP
# Moved PEP_income_statement.csv to ./Dataset_500_EMPRESAS/PEP
# Moved AAPL_cash_flow.csv to ./Dataset_500_EMPRESAS/AAPL
# Moved AAPL_info.json to ./Dataset_500_EMPRESAS/AAPL
# Moved AAPL_income_statement.csv to ./Dataset_500_EMPRESAS/AAPL
# Moved AAPL_historico.csv to ./Dataset_500_EMPRESAS/AAPL
# Moved AAPL_balance_sheet.csv to ./Dataset_500_EMPRESAS/AAPL
# Moved LH_cash_flow.csv to ./Dataset_500_EMPRESAS/LH
# Moved LH_info.json to ./Dataset_500_EMPRESAS/LH
# Moved LH_balance_sheet.csv to ./Dataset_500_EMPRESAS/LH
# Moved LH_income_statement.csv to ./Dataset_500_EMPRESAS/LH
# Moved LH_historico.csv to ./Dataset_500_EMPRESAS/LH
# Moved VRSN_cash_flow.csv to ./Dataset_500_EMPRESAS/VRSN
# Moved VRSN_balance_sheet.csv to ./Dataset_500_EMPRESAS/VRSN
# Moved VRSN_income_statement.csv to ./Dataset_500_EMPRESAS/VRSN
# Moved VRSN_historico.csv to ./Dataset_500_EMPRESAS/VRSN
# Moved VRSN_info.json to ./Dataset_500_EMPRESAS/VRSN
# Moved TSLA_income_statement.csv to ./Dataset_500_EMPRESAS/TSLA
# Moved TSLA_balance_sheet.csv to ./Dataset_500_EMPRESAS/TSLA
# Moved TSLA_historico.csv to ./Dataset_500_EMPRESAS/TSLA
# Moved TSLA_info.json to ./Dataset_500_EMPRESAS/TSLA
# Moved TSLA_cash_flow.csv to ./Dataset_500_EMPRESAS/TSLA
# Moved NDSN_cash_flow.csv to ./Dataset_500_EMPRESAS/NDSN
# Moved NDSN_balance_sheet.csv to ./Dataset_500_EMPRESAS/NDSN
# Moved NDSN_historico.csv to ./Dataset_500_EMPRESAS/NDSN
# Moved NDSN_income_statement.csv to ./Dataset_500_EMPRESAS/NDSN
# Moved NDSN_info.json to ./Dataset_500_EMPRESAS/NDSN
# Moved PPG_info.json to ./Dataset_500_EMPRESAS/PPG
# Moved PPG_income_statement.csv to ./Dataset_500_EMPRESAS/PPG
# Moved PPG_historico.csv to ./Dataset_500_EMPRESAS/PPG
# Moved PPG_balance_sheet.csv to ./Dataset_500_EMPRESAS/PPG
# Moved PPG_cash_flow.csv to ./Dataset_500_EMPRESAS/PPG
# Moved NI_historico.csv to ./Dataset_500_EMPRESAS/NI
# Moved NI_info.json to ./Dataset_500_EMPRESAS/NI
# Moved NI_balance_sheet.csv to ./Dataset_500_EMPRESAS/NI
# Moved NI_cash_flow.csv to ./Dataset_500_EMPRESAS/NI
# Moved NI_income_statement.csv to ./Dataset_500_EMPRESAS/NI
# Moved GPN_info.json to ./Dataset_500_EMPRESAS/GPN
# Moved GPN_income_statement.csv to ./Dataset_500_EMPRESAS/GPN
# Moved GPN_cash_flow.csv to ./Dataset_500_EMPRESAS/GPN
# Moved GPN_balance_sheet.csv to ./Dataset_500_EMPRESAS/GPN
# Moved GPN_historico.csv to ./Dataset_500_EMPRESAS/GPN
# Moved EA_balance_sheet.csv to ./Dataset_500_EMPRESAS/EA
# Moved EA_cash_flow.csv to ./Dataset_500_EMPRESAS/EA
# Moved EA_info.json to ./Dataset_500_EMPRESAS/EA
# Moved EA_historico.csv to ./Dataset_500_EMPRESAS/EA
# Moved EA_income_statement.csv to ./Dataset_500_EMPRESAS/EA
# Moved VTR_income_statement.csv to ./Dataset_500_EMPRESAS/VTR
# Moved VTR_historico.csv to ./Dataset_500_EMPRESAS/VTR
# Moved VTR_balance_sheet.csv to ./Dataset_500_EMPRESAS/VTR
# Moved VTR_cash_flow.csv to ./Dataset_500_EMPRESAS/VTR
# Moved VTR_info.json to ./Dataset_500_EMPRESAS/VTR
# Moved FE_info.json to ./Dataset_500_EMPRESAS/FE
# Moved FE_income_statement.csv to ./Dataset_500_EMPRESAS/FE
# Moved FE_balance_sheet.csv to ./Dataset_500_EMPRESAS/FE
# Moved FE_cash_flow.csv to ./Dataset_500_EMPRESAS/FE
# Moved FE_historico.csv to ./Dataset_500_EMPRESAS/FE
# Moved PNW_historico.csv to ./Dataset_500_EMPRESAS/PNW
# Moved PNW_balance_sheet.csv to ./Dataset_500_EMPRESAS/PNW
# Moved PNW_cash_flow.csv to ./Dataset_500_EMPRESAS/PNW
# Moved PNW_income_statement.csv to ./Dataset_500_EMPRESAS/PNW
# Moved PNW_info.json to ./Dataset_500_EMPRESAS/PNW
# Moved IRM_cash_flow.csv to ./Dataset_500_EMPRESAS/IRM
# Moved IRM_balance_sheet.csv to ./Dataset_500_EMPRESAS/IRM
# Moved IRM_info.json to ./Dataset_500_EMPRESAS/IRM
# Moved IRM_income_statement.csv to ./Dataset_500_EMPRESAS/IRM
# Moved IRM_historico.csv to ./Dataset_500_EMPRESAS/IRM
# Moved MRK_income_statement.csv to ./Dataset_500_EMPRESAS/MRK
# Moved MRK_balance_sheet.csv to ./Dataset_500_EMPRESAS/MRK
# Moved MRK_cash_flow.csv to ./Dataset_500_EMPRESAS/MRK
# Moved MRK_historico.csv to ./Dataset_500_EMPRESAS/MRK
# Moved MRK_info.json to ./Dataset_500_EMPRESAS/MRK
# Moved CL_income_statement.csv to ./Dataset_500_EMPRESAS/CL
# Moved CL_cash_flow.csv to ./Dataset_500_EMPRESAS/CL
# Moved CL_info.json to ./Dataset_500_EMPRESAS/CL
# Moved CL_balance_sheet.csv to ./Dataset_500_EMPRESAS/CL
# Moved CL_historico.csv to ./Dataset_500_EMPRESAS/CL
# Moved ESS_cash_flow.csv to ./Dataset_500_EMPRESAS/ESS
# Moved ESS_income_statement.csv to ./Dataset_500_EMPRESAS/ESS
# Moved ESS_info.json to ./Dataset_500_EMPRESAS/ESS
# Moved ESS_historico.csv to ./Dataset_500_EMPRESAS/ESS
# Moved ESS_balance_sheet.csv to ./Dataset_500_EMPRESAS/ESS
# Moved TKO_info.json to ./Dataset_500_EMPRESAS/TKO
# Moved TKO_balance_sheet.csv to ./Dataset_500_EMPRESAS/TKO
# Moved TKO_cash_flow.csv to ./Dataset_500_EMPRESAS/TKO
# Moved TKO_historico.csv to ./Dataset_500_EMPRESAS/TKO
# Moved TKO_income_statement.csv to ./Dataset_500_EMPRESAS/TKO
# Moved KHC_income_statement.csv to ./Dataset_500_EMPRESAS/KHC
# Moved KHC_cash_flow.csv to ./Dataset_500_EMPRESAS/KHC
# Moved KHC_historico.csv to ./Dataset_500_EMPRESAS/KHC
# Moved KHC_balance_sheet.csv to ./Dataset_500_EMPRESAS/KHC
# Moved KHC_info.json to ./Dataset_500_EMPRESAS/KHC
# Moved CHRW_historico.csv to ./Dataset_500_EMPRESAS/CHRW
# Moved CHRW_info.json to ./Dataset_500_EMPRESAS/CHRW
# Moved CHRW_income_statement.csv to ./Dataset_500_EMPRESAS/CHRW
# Moved CHRW_balance_sheet.csv to ./Dataset_500_EMPRESAS/CHRW
# Moved CHRW_cash_flow.csv to ./Dataset_500_EMPRESAS/CHRW
# Moved HSY_income_statement.csv to ./Dataset_500_EMPRESAS/HSY
# Moved HSY_balance_sheet.csv to ./Dataset_500_EMPRESAS/HSY
# Moved HSY_info.json to ./Dataset_500_EMPRESAS/HSY
# Moved HSY_historico.csv to ./Dataset_500_EMPRESAS/HSY
# Moved HSY_cash_flow.csv to ./Dataset_500_EMPRESAS/HSY
# Moved SWK_balance_sheet.csv to ./Dataset_500_EMPRESAS/SWK
# Moved SWK_historico.csv to ./Dataset_500_EMPRESAS/SWK
# Moved SWK_info.json to ./Dataset_500_EMPRESAS/SWK
# Moved SWK_income_statement.csv to ./Dataset_500_EMPRESAS/SWK
# Moved SWK_cash_flow.csv to ./Dataset_500_EMPRESAS/SWK
# Moved KMI_balance_sheet.csv to ./Dataset_500_EMPRESAS/KMI
# Moved KMI_cash_flow.csv to ./Dataset_500_EMPRESAS/KMI
# Moved KMI_historico.csv to ./Dataset_500_EMPRESAS/KMI
# Moved KMI_income_statement.csv to ./Dataset_500_EMPRESAS/KMI
# Moved KMI_info.json to ./Dataset_500_EMPRESAS/KMI
# Moved UNH_cash_flow.csv to ./Dataset_500_EMPRESAS/UNH
# Moved UNH_balance_sheet.csv to ./Dataset_500_EMPRESAS/UNH
# Moved UNH_info.json to ./Dataset_500_EMPRESAS/UNH
# Moved UNH_historico.csv to ./Dataset_500_EMPRESAS/UNH
# Moved UNH_income_statement.csv to ./Dataset_500_EMPRESAS/UNH
# Moved TDY_cash_flow.csv to ./Dataset_500_EMPRESAS/TDY
# Moved TDY_balance_sheet.csv to ./Dataset_500_EMPRESAS/TDY
# Moved TDY_income_statement.csv to ./Dataset_500_EMPRESAS/TDY
# Moved TDY_historico.csv to ./Dataset_500_EMPRESAS/TDY
# Moved TDY_info.json to ./Dataset_500_EMPRESAS/TDY
# Moved AMGN_info.json to ./Dataset_500_EMPRESAS/AMGN
# Moved AMGN_historico.csv to ./Dataset_500_EMPRESAS/AMGN
# Moved AMGN_income_statement.csv to ./Dataset_500_EMPRESAS/AMGN
# Moved AMGN_balance_sheet.csv to ./Dataset_500_EMPRESAS/AMGN
# Moved AMGN_cash_flow.csv to ./Dataset_500_EMPRESAS/AMGN
# Moved WELL_historico.csv to ./Dataset_500_EMPRESAS/WELL
# Moved WELL_balance_sheet.csv to ./Dataset_500_EMPRESAS/WELL
# Moved WELL_income_statement.csv to ./Dataset_500_EMPRESAS/WELL
# Moved WELL_info.json to ./Dataset_500_EMPRESAS/WELL
# Moved WELL_cash_flow.csv to ./Dataset_500_EMPRESAS/WELL
# Moved D_historico.csv to ./Dataset_500_EMPRESAS/D
# Moved D_info.json to ./Dataset_500_EMPRESAS/D
# Moved D_income_statement.csv to ./Dataset_500_EMPRESAS/D
# Moved D_cash_flow.csv to ./Dataset_500_EMPRESAS/D
# Moved D_balance_sheet.csv to ./Dataset_500_EMPRESAS/D
# Moved EG_income_statement.csv to ./Dataset_500_EMPRESAS/EG
# Moved EG_historico.csv to ./Dataset_500_EMPRESAS/EG
# Moved EG_balance_sheet.csv to ./Dataset_500_EMPRESAS/EG
# Moved EG_info.json to ./Dataset_500_EMPRESAS/EG
# Moved EG_cash_flow.csv to ./Dataset_500_EMPRESAS/EG
# Moved OXY_info.json to ./Dataset_500_EMPRESAS/OXY
# Moved OXY_historico.csv to ./Dataset_500_EMPRESAS/OXY
# Moved OXY_balance_sheet.csv to ./Dataset_500_EMPRESAS/OXY
# Moved OXY_income_statement.csv to ./Dataset_500_EMPRESAS/OXY
# Moved OXY_cash_flow.csv to ./Dataset_500_EMPRESAS/OXY
# Moved INVH_historico.csv to ./Dataset_500_EMPRESAS/INVH
# Moved INVH_balance_sheet.csv to ./Dataset_500_EMPRESAS/INVH
# Moved INVH_info.json to ./Dataset_500_EMPRESAS/INVH
# Moved INVH_income_statement.csv to ./Dataset_500_EMPRESAS/INVH
# Moved INVH_cash_flow.csv to ./Dataset_500_EMPRESAS/INVH
# Moved RSG_info.json to ./Dataset_500_EMPRESAS/RSG
# Moved RSG_cash_flow.csv to ./Dataset_500_EMPRESAS/RSG
# Moved RSG_balance_sheet.csv to ./Dataset_500_EMPRESAS/RSG
# Moved RSG_income_statement.csv to ./Dataset_500_EMPRESAS/RSG
# Moved RSG_historico.csv to ./Dataset_500_EMPRESAS/RSG
# Moved AOS_info.json to ./Dataset_500_EMPRESAS/AOS
# Moved AOS_cash_flow.csv to ./Dataset_500_EMPRESAS/AOS
# Moved AOS_historico.csv to ./Dataset_500_EMPRESAS/AOS
# Moved AOS_balance_sheet.csv to ./Dataset_500_EMPRESAS/AOS
# Moved AOS_income_statement.csv to ./Dataset_500_EMPRESAS/AOS
# Moved CBOE_historico.csv to ./Dataset_500_EMPRESAS/CBOE
# Moved CBOE_info.json to ./Dataset_500_EMPRESAS/CBOE
# Moved CBOE_cash_flow.csv to ./Dataset_500_EMPRESAS/CBOE
# Moved CBOE_income_statement.csv to ./Dataset_500_EMPRESAS/CBOE
# Moved CBOE_balance_sheet.csv to ./Dataset_500_EMPRESAS/CBOE
# Moved AEE_cash_flow.csv to ./Dataset_500_EMPRESAS/AEE
# Moved AEE_income_statement.csv to ./Dataset_500_EMPRESAS/AEE
# Moved AEE_info.json to ./Dataset_500_EMPRESAS/AEE
# Moved AEE_historico.csv to ./Dataset_500_EMPRESAS/AEE
# Moved AEE_balance_sheet.csv to ./Dataset_500_EMPRESAS/AEE
# Moved RL_historico.csv to ./Dataset_500_EMPRESAS/RL
# Moved RL_income_statement.csv to ./Dataset_500_EMPRESAS/RL
# Moved RL_cash_flow.csv to ./Dataset_500_EMPRESAS/RL
# Moved RL_info.json to ./Dataset_500_EMPRESAS/RL
# Moved RL_balance_sheet.csv to ./Dataset_500_EMPRESAS/RL
# Moved BKR_balance_sheet.csv to ./Dataset_500_EMPRESAS/BKR
# Moved BKR_cash_flow.csv to ./Dataset_500_EMPRESAS/BKR
# Moved BKR_historico.csv to ./Dataset_500_EMPRESAS/BKR
# Moved BKR_info.json to ./Dataset_500_EMPRESAS/BKR
# Moved BKR_income_statement.csv to ./Dataset_500_EMPRESAS/BKR
# Moved ISRG_cash_flow.csv to ./Dataset_500_EMPRESAS/ISRG
# Moved ISRG_balance_sheet.csv to ./Dataset_500_EMPRESAS/ISRG
# Moved ISRG_info.json to ./Dataset_500_EMPRESAS/ISRG
# Moved ISRG_income_statement.csv to ./Dataset_500_EMPRESAS/ISRG
# Moved ISRG_historico.csv to ./Dataset_500_EMPRESAS/ISRG
# Moved BLK_historico.csv to ./Dataset_500_EMPRESAS/BLK
# Moved BLK_info.json to ./Dataset_500_EMPRESAS/BLK
# Moved BLK_income_statement.csv to ./Dataset_500_EMPRESAS/BLK
# Moved BLK_cash_flow.csv to ./Dataset_500_EMPRESAS/BLK
# Moved BLK_balance_sheet.csv to ./Dataset_500_EMPRESAS/BLK
# Moved MKC_info.json to ./Dataset_500_EMPRESAS/MKC
# Moved MKC_cash_flow.csv to ./Dataset_500_EMPRESAS/MKC
# Moved MKC_historico.csv to ./Dataset_500_EMPRESAS/MKC
# Moved MKC_income_statement.csv to ./Dataset_500_EMPRESAS/MKC
# Moved MKC_balance_sheet.csv to ./Dataset_500_EMPRESAS/MKC
# Moved RF_income_statement.csv to ./Dataset_500_EMPRESAS/RF
# Moved RF_historico.csv to ./Dataset_500_EMPRESAS/RF
# Moved RF_balance_sheet.csv to ./Dataset_500_EMPRESAS/RF
# Moved RF_info.json to ./Dataset_500_EMPRESAS/RF
# Moved RF_cash_flow.csv to ./Dataset_500_EMPRESAS/RF
# Moved APD_balance_sheet.csv to ./Dataset_500_EMPRESAS/APD
# Moved APD_cash_flow.csv to ./Dataset_500_EMPRESAS/APD
# Moved APD_info.json to ./Dataset_500_EMPRESAS/APD
# Moved APD_income_statement.csv to ./Dataset_500_EMPRESAS/APD
# Moved APD_historico.csv to ./Dataset_500_EMPRESAS/APD
# Moved BRO_income_statement.csv to ./Dataset_500_EMPRESAS/BRO
# Moved BRO_info.json to ./Dataset_500_EMPRESAS/BRO
# Moved BRO_cash_flow.csv to ./Dataset_500_EMPRESAS/BRO
# Moved BRO_balance_sheet.csv to ./Dataset_500_EMPRESAS/BRO
# Moved BRO_historico.csv to ./Dataset_500_EMPRESAS/BRO
# Moved AJG_historico.csv to ./Dataset_500_EMPRESAS/AJG
# Moved AJG_income_statement.csv to ./Dataset_500_EMPRESAS/AJG
# Moved AJG_info.json to ./Dataset_500_EMPRESAS/AJG
# Moved AJG_balance_sheet.csv to ./Dataset_500_EMPRESAS/AJG
# Moved AJG_cash_flow.csv to ./Dataset_500_EMPRESAS/AJG
# Moved HST_historico.csv to ./Dataset_500_EMPRESAS/HST
# Moved HST_info.json to ./Dataset_500_EMPRESAS/HST
# Moved HST_income_statement.csv to ./Dataset_500_EMPRESAS/HST
# Moved HST_balance_sheet.csv to ./Dataset_500_EMPRESAS/HST
# Moved HST_cash_flow.csv to ./Dataset_500_EMPRESAS/HST
# Moved AVGO_cash_flow.csv to ./Dataset_500_EMPRESAS/AVGO
# Moved AVGO_income_statement.csv to ./Dataset_500_EMPRESAS/AVGO
# Moved AVGO_balance_sheet.csv to ./Dataset_500_EMPRESAS/AVGO
# Moved AVGO_historico.csv to ./Dataset_500_EMPRESAS/AVGO
# Moved AVGO_info.json to ./Dataset_500_EMPRESAS/AVGO
# Moved GEHC_cash_flow.csv to ./Dataset_500_EMPRESAS/GEHC
# Moved GEHC_balance_sheet.csv to ./Dataset_500_EMPRESAS/GEHC
# Moved GEHC_info.json to ./Dataset_500_EMPRESAS/GEHC
# Moved GEHC_income_statement.csv to ./Dataset_500_EMPRESAS/GEHC
# Moved GEHC_historico.csv to ./Dataset_500_EMPRESAS/GEHC
# Moved BA_income_statement.csv to ./Dataset_500_EMPRESAS/BA
# Moved BA_cash_flow.csv to ./Dataset_500_EMPRESAS/BA
# Moved BA_info.json to ./Dataset_500_EMPRESAS/BA
# Moved BA_balance_sheet.csv to ./Dataset_500_EMPRESAS/BA
# Moved BA_historico.csv to ./Dataset_500_EMPRESAS/BA
# Moved EQIX_balance_sheet.csv to ./Dataset_500_EMPRESAS/EQIX
# Moved EQIX_income_statement.csv to ./Dataset_500_EMPRESAS/EQIX
# Moved EQIX_historico.csv to ./Dataset_500_EMPRESAS/EQIX
# Moved EQIX_info.json to ./Dataset_500_EMPRESAS/EQIX
# Moved EQIX_cash_flow.csv to ./Dataset_500_EMPRESAS/EQIX
# Moved UNP_balance_sheet.csv to ./Dataset_500_EMPRESAS/UNP
# Moved UNP_cash_flow.csv to ./Dataset_500_EMPRESAS/UNP
# Moved UNP_income_statement.csv to ./Dataset_500_EMPRESAS/UNP
# Moved UNP_info.json to ./Dataset_500_EMPRESAS/UNP
# Moved UNP_historico.csv to ./Dataset_500_EMPRESAS/UNP
# Moved EFX_income_statement.csv to ./Dataset_500_EMPRESAS/EFX
# Moved EFX_info.json to ./Dataset_500_EMPRESAS/EFX
# Moved EFX_cash_flow.csv to ./Dataset_500_EMPRESAS/EFX
# Moved EFX_balance_sheet.csv to ./Dataset_500_EMPRESAS/EFX
# Moved EFX_historico.csv to ./Dataset_500_EMPRESAS/EFX
# Moved TECH_cash_flow.csv to ./Dataset_500_EMPRESAS/TECH
# Moved TECH_balance_sheet.csv to ./Dataset_500_EMPRESAS/TECH
# Moved TECH_info.json to ./Dataset_500_EMPRESAS/TECH
# Moved TECH_historico.csv to ./Dataset_500_EMPRESAS/TECH
# Moved TECH_income_statement.csv to ./Dataset_500_EMPRESAS/TECH
# Moved ACGL_info.json to ./Dataset_500_EMPRESAS/ACGL
# Moved ACGL_cash_flow.csv to ./Dataset_500_EMPRESAS/ACGL
# Moved ACGL_historico.csv to ./Dataset_500_EMPRESAS/ACGL
# Moved ACGL_income_statement.csv to ./Dataset_500_EMPRESAS/ACGL
# Moved ACGL_balance_sheet.csv to ./Dataset_500_EMPRESAS/ACGL
# Moved IT_balance_sheet.csv to ./Dataset_500_EMPRESAS/IT
# Moved IT_cash_flow.csv to ./Dataset_500_EMPRESAS/IT
# Moved IT_historico.csv to ./Dataset_500_EMPRESAS/IT
# Moved IT_income_statement.csv to ./Dataset_500_EMPRESAS/IT
# Moved IT_info.json to ./Dataset_500_EMPRESAS/IT
# Moved JCI_cash_flow.csv to ./Dataset_500_EMPRESAS/JCI
# Moved JCI_balance_sheet.csv to ./Dataset_500_EMPRESAS/JCI
# Moved JCI_income_statement.csv to ./Dataset_500_EMPRESAS/JCI
# Moved JCI_historico.csv to ./Dataset_500_EMPRESAS/JCI
# Moved JCI_info.json to ./Dataset_500_EMPRESAS/JCI
# Moved TSCO_info.json to ./Dataset_500_EMPRESAS/TSCO
# Moved TSCO_balance_sheet.csv to ./Dataset_500_EMPRESAS/TSCO
# Moved TSCO_historico.csv to ./Dataset_500_EMPRESAS/TSCO
# Moved TSCO_income_statement.csv to ./Dataset_500_EMPRESAS/TSCO
# Moved TSCO_cash_flow.csv to ./Dataset_500_EMPRESAS/TSCO
# Moved IP_balance_sheet.csv to ./Dataset_500_EMPRESAS/IP
# Moved IP_info.json to ./Dataset_500_EMPRESAS/IP
# Moved IP_cash_flow.csv to ./Dataset_500_EMPRESAS/IP
# Moved IP_historico.csv to ./Dataset_500_EMPRESAS/IP
# Moved IP_income_statement.csv to ./Dataset_500_EMPRESAS/IP
# Moved FRT_income_statement.csv to ./Dataset_500_EMPRESAS/FRT
# Moved FRT_historico.csv to ./Dataset_500_EMPRESAS/FRT
# Moved FRT_balance_sheet.csv to ./Dataset_500_EMPRESAS/FRT
# Moved FRT_info.json to ./Dataset_500_EMPRESAS/FRT
# Moved FRT_cash_flow.csv to ./Dataset_500_EMPRESAS/FRT
# Moved WY_balance_sheet.csv to ./Dataset_500_EMPRESAS/WY
# Moved WY_historico.csv to ./Dataset_500_EMPRESAS/WY
# Moved WY_income_statement.csv to ./Dataset_500_EMPRESAS/WY
# Moved WY_cash_flow.csv to ./Dataset_500_EMPRESAS/WY
# Moved WY_info.json to ./Dataset_500_EMPRESAS/WY
# Moved GEN_historico.csv to ./Dataset_500_EMPRESAS/GEN
# Moved GEN_balance_sheet.csv to ./Dataset_500_EMPRESAS/GEN
# Moved GEN_income_statement.csv to ./Dataset_500_EMPRESAS/GEN
# Moved GEN_info.json to ./Dataset_500_EMPRESAS/GEN
# Moved GEN_cash_flow.csv to ./Dataset_500_EMPRESAS/GEN
# Moved GPC_info.json to ./Dataset_500_EMPRESAS/GPC
# Moved GPC_balance_sheet.csv to ./Dataset_500_EMPRESAS/GPC
# Moved GPC_cash_flow.csv to ./Dataset_500_EMPRESAS/GPC
# Moved GPC_income_statement.csv to ./Dataset_500_EMPRESAS/GPC
# Moved GPC_historico.csv to ./Dataset_500_EMPRESAS/GPC
# Moved HBAN_balance_sheet.csv to ./Dataset_500_EMPRESAS/HBAN
# Moved HBAN_info.json to ./Dataset_500_EMPRESAS/HBAN
# Moved HBAN_cash_flow.csv to ./Dataset_500_EMPRESAS/HBAN
# Moved HBAN_historico.csv to ./Dataset_500_EMPRESAS/HBAN
# Moved HBAN_income_statement.csv to ./Dataset_500_EMPRESAS/HBAN
# Moved ANET_balance_sheet.csv to ./Dataset_500_EMPRESAS/ANET
# Moved ANET_income_statement.csv to ./Dataset_500_EMPRESAS/ANET
# Moved ANET_historico.csv to ./Dataset_500_EMPRESAS/ANET
# Moved ANET_cash_flow.csv to ./Dataset_500_EMPRESAS/ANET
# Moved ANET_info.json to ./Dataset_500_EMPRESAS/ANET
# Moved FTV_info.json to ./Dataset_500_EMPRESAS/FTV
# Moved FTV_cash_flow.csv to ./Dataset_500_EMPRESAS/FTV
# Moved FTV_balance_sheet.csv to ./Dataset_500_EMPRESAS/FTV
# Moved FTV_historico.csv to ./Dataset_500_EMPRESAS/FTV
# Moved FTV_income_statement.csv to ./Dataset_500_EMPRESAS/FTV
# Moved GIS_cash_flow.csv to ./Dataset_500_EMPRESAS/GIS
# Moved GIS_info.json to ./Dataset_500_EMPRESAS/GIS
# Moved GIS_balance_sheet.csv to ./Dataset_500_EMPRESAS/GIS
# Moved GIS_income_statement.csv to ./Dataset_500_EMPRESAS/GIS
# Moved GIS_historico.csv to ./Dataset_500_EMPRESAS/GIS
# Moved ES_cash_flow.csv to ./Dataset_500_EMPRESAS/ES
# Moved ES_info.json to ./Dataset_500_EMPRESAS/ES
# Moved ES_income_statement.csv to ./Dataset_500_EMPRESAS/ES
# Moved ES_balance_sheet.csv to ./Dataset_500_EMPRESAS/ES
# Moved ES_historico.csv to ./Dataset_500_EMPRESAS/ES
# Moved EW_cash_flow.csv to ./Dataset_500_EMPRESAS/EW
# Moved EW_income_statement.csv to ./Dataset_500_EMPRESAS/EW
# Moved EW_info.json to ./Dataset_500_EMPRESAS/EW
# Moved EW_historico.csv to ./Dataset_500_EMPRESAS/EW
# Moved EW_balance_sheet.csv to ./Dataset_500_EMPRESAS/EW
# Moved LOW_info.json to ./Dataset_500_EMPRESAS/LOW
# Moved LOW_historico.csv to ./Dataset_500_EMPRESAS/LOW
# Moved LOW_cash_flow.csv to ./Dataset_500_EMPRESAS/LOW
# Moved LOW_income_statement.csv to ./Dataset_500_EMPRESAS/LOW
# Moved LOW_balance_sheet.csv to ./Dataset_500_EMPRESAS/LOW
# Moved DTE_income_statement.csv to ./Dataset_500_EMPRESAS/DTE
# Moved DTE_cash_flow.csv to ./Dataset_500_EMPRESAS/DTE
# Moved DTE_historico.csv to ./Dataset_500_EMPRESAS/DTE
# Moved DTE_balance_sheet.csv to ./Dataset_500_EMPRESAS/DTE
# Moved DTE_info.json to ./Dataset_500_EMPRESAS/DTE
# Moved SYK_income_statement.csv to ./Dataset_500_EMPRESAS/SYK
# Moved SYK_balance_sheet.csv to ./Dataset_500_EMPRESAS/SYK
# Moved SYK_historico.csv to ./Dataset_500_EMPRESAS/SYK
# Moved SYK_cash_flow.csv to ./Dataset_500_EMPRESAS/SYK
# Moved SYK_info.json to ./Dataset_500_EMPRESAS/SYK
# Moved FSLR_balance_sheet.csv to ./Dataset_500_EMPRESAS/FSLR
# Moved FSLR_historico.csv to ./Dataset_500_EMPRESAS/FSLR
# Moved FSLR_cash_flow.csv to ./Dataset_500_EMPRESAS/FSLR
# Moved FSLR_info.json to ./Dataset_500_EMPRESAS/FSLR
# Moved FSLR_income_statement.csv to ./Dataset_500_EMPRESAS/FSLR
# Moved COO_historico.csv to ./Dataset_500_EMPRESAS/COO
# Moved COO_income_statement.csv to ./Dataset_500_EMPRESAS/COO
# Moved COO_info.json to ./Dataset_500_EMPRESAS/COO
# Moved COO_balance_sheet.csv to ./Dataset_500_EMPRESAS/COO
# Moved COO_cash_flow.csv to ./Dataset_500_EMPRESAS/COO
# Moved CPRT_cash_flow.csv to ./Dataset_500_EMPRESAS/CPRT
# Moved CPRT_income_statement.csv to ./Dataset_500_EMPRESAS/CPRT
# Moved CPRT_info.json to ./Dataset_500_EMPRESAS/CPRT
# Moved CPRT_historico.csv to ./Dataset_500_EMPRESAS/CPRT
# Moved CPRT_balance_sheet.csv to ./Dataset_500_EMPRESAS/CPRT
# Moved ACN_balance_sheet.csv to ./Dataset_500_EMPRESAS/ACN
# Moved ACN_info.json to ./Dataset_500_EMPRESAS/ACN
# Moved ACN_historico.csv to ./Dataset_500_EMPRESAS/ACN
# Moved ACN_income_statement.csv to ./Dataset_500_EMPRESAS/ACN
# Moved ACN_cash_flow.csv to ./Dataset_500_EMPRESAS/ACN
# Moved HON_income_statement.csv to ./Dataset_500_EMPRESAS/HON
# Moved HON_historico.csv to ./Dataset_500_EMPRESAS/HON
# Moved HON_cash_flow.csv to ./Dataset_500_EMPRESAS/HON
# Moved HON_balance_sheet.csv to ./Dataset_500_EMPRESAS/HON
# Moved HON_info.json to ./Dataset_500_EMPRESAS/HON
# Moved PCAR_info.json to ./Dataset_500_EMPRESAS/PCAR
# Moved PCAR_historico.csv to ./Dataset_500_EMPRESAS/PCAR
# Moved PCAR_balance_sheet.csv to ./Dataset_500_EMPRESAS/PCAR
# Moved PCAR_cash_flow.csv to ./Dataset_500_EMPRESAS/PCAR
# Moved PCAR_income_statement.csv to ./Dataset_500_EMPRESAS/PCAR
# Moved DAY_balance_sheet.csv to ./Dataset_500_EMPRESAS/DAY
# Moved DAY_historico.csv to ./Dataset_500_EMPRESAS/DAY
# Moved DAY_info.json to ./Dataset_500_EMPRESAS/DAY
# Moved DAY_cash_flow.csv to ./Dataset_500_EMPRESAS/DAY
# Moved DAY_income_statement.csv to ./Dataset_500_EMPRESAS/DAY
# Moved LYB_info.json to ./Dataset_500_EMPRESAS/LYB
# Moved LYB_income_statement.csv to ./Dataset_500_EMPRESAS/LYB
# Moved LYB_cash_flow.csv to ./Dataset_500_EMPRESAS/LYB
# Moved LYB_balance_sheet.csv to ./Dataset_500_EMPRESAS/LYB
# Moved LYB_historico.csv to ./Dataset_500_EMPRESAS/LYB
# Moved SBAC_cash_flow.csv to ./Dataset_500_EMPRESAS/SBAC
# Moved SBAC_balance_sheet.csv to ./Dataset_500_EMPRESAS/SBAC
# Moved SBAC_income_statement.csv to ./Dataset_500_EMPRESAS/SBAC
# Moved SBAC_historico.csv to ./Dataset_500_EMPRESAS/SBAC
# Moved SBAC_info.json to ./Dataset_500_EMPRESAS/SBAC
# Moved VICI_historico.csv to ./Dataset_500_EMPRESAS/VICI
# Moved VICI_income_statement.csv to ./Dataset_500_EMPRESAS/VICI
# Moved VICI_balance_sheet.csv to ./Dataset_500_EMPRESAS/VICI
# Moved VICI_cash_flow.csv to ./Dataset_500_EMPRESAS/VICI
# Moved VICI_info.json to ./Dataset_500_EMPRESAS/VICI
# Moved ALGN_historico.csv to ./Dataset_500_EMPRESAS/ALGN
# Moved ALGN_income_statement.csv to ./Dataset_500_EMPRESAS/ALGN
# Moved ALGN_cash_flow.csv to ./Dataset_500_EMPRESAS/ALGN
# Moved ALGN_info.json to ./Dataset_500_EMPRESAS/ALGN
# Moved ALGN_balance_sheet.csv to ./Dataset_500_EMPRESAS/ALGN
# Moved PLTR_balance_sheet.csv to ./Dataset_500_EMPRESAS/PLTR
# Moved PLTR_cash_flow.csv to ./Dataset_500_EMPRESAS/PLTR
# Moved PLTR_historico.csv to ./Dataset_500_EMPRESAS/PLTR
# Moved PLTR_info.json to ./Dataset_500_EMPRESAS/PLTR
# Moved PLTR_income_statement.csv to ./Dataset_500_EMPRESAS/PLTR
# Moved JBHT_balance_sheet.csv to ./Dataset_500_EMPRESAS/JBHT
# Moved JBHT_cash_flow.csv to ./Dataset_500_EMPRESAS/JBHT
# Moved JBHT_historico.csv to ./Dataset_500_EMPRESAS/JBHT
# Moved JBHT_info.json to ./Dataset_500_EMPRESAS/JBHT
# Moved JBHT_income_statement.csv to ./Dataset_500_EMPRESAS/JBHT
# Moved HUBB_info.json to ./Dataset_500_EMPRESAS/HUBB
# Moved HUBB_income_statement.csv to ./Dataset_500_EMPRESAS/HUBB
# Moved HUBB_cash_flow.csv to ./Dataset_500_EMPRESAS/HUBB
# Moved HUBB_historico.csv to ./Dataset_500_EMPRESAS/HUBB
# Moved HUBB_balance_sheet.csv to ./Dataset_500_EMPRESAS/HUBB
# Moved TPL_income_statement.csv to ./Dataset_500_EMPRESAS/TPL
# Moved TPL_historico.csv to ./Dataset_500_EMPRESAS/TPL
# Moved TPL_info.json to ./Dataset_500_EMPRESAS/TPL
# Moved TPL_cash_flow.csv to ./Dataset_500_EMPRESAS/TPL
# Moved TPL_balance_sheet.csv to ./Dataset_500_EMPRESAS/TPL
# Moved K_cash_flow.csv to ./Dataset_500_EMPRESAS/K
# Moved K_income_statement.csv to ./Dataset_500_EMPRESAS/K
# Moved K_balance_sheet.csv to ./Dataset_500_EMPRESAS/K
# Moved K_historico.csv to ./Dataset_500_EMPRESAS/K
# Moved K_info.json to ./Dataset_500_EMPRESAS/K
# Moved LMT_historico.csv to ./Dataset_500_EMPRESAS/LMT
# Moved LMT_balance_sheet.csv to ./Dataset_500_EMPRESAS/LMT
# Moved LMT_income_statement.csv to ./Dataset_500_EMPRESAS/LMT
# Moved LMT_info.json to ./Dataset_500_EMPRESAS/LMT
# Moved LMT_cash_flow.csv to ./Dataset_500_EMPRESAS/LMT
# Moved NTAP_historico.csv to ./Dataset_500_EMPRESAS/NTAP
# Moved NTAP_info.json to ./Dataset_500_EMPRESAS/NTAP
# Moved NTAP_income_statement.csv to ./Dataset_500_EMPRESAS/NTAP
# Moved NTAP_balance_sheet.csv to ./Dataset_500_EMPRESAS/NTAP
# Moved NTAP_cash_flow.csv to ./Dataset_500_EMPRESAS/NTAP
# Moved JNPR_info.json to ./Dataset_500_EMPRESAS/JNPR
# Moved JNPR_historico.csv to ./Dataset_500_EMPRESAS/JNPR
# Moved JNPR_cash_flow.csv to ./Dataset_500_EMPRESAS/JNPR
# Moved JNPR_balance_sheet.csv to ./Dataset_500_EMPRESAS/JNPR
# Moved JNPR_income_statement.csv to ./Dataset_500_EMPRESAS/JNPR
# Moved AMCR_balance_sheet.csv to ./Dataset_500_EMPRESAS/AMCR
# Moved AMCR_info.json to ./Dataset_500_EMPRESAS/AMCR
# Moved AMCR_historico.csv to ./Dataset_500_EMPRESAS/AMCR
# Moved AMCR_cash_flow.csv to ./Dataset_500_EMPRESAS/AMCR
# Moved AMCR_income_statement.csv to ./Dataset_500_EMPRESAS/AMCR
# Moved PHM_balance_sheet.csv to ./Dataset_500_EMPRESAS/PHM
# Moved PHM_cash_flow.csv to ./Dataset_500_EMPRESAS/PHM
# Moved PHM_historico.csv to ./Dataset_500_EMPRESAS/PHM
# Moved PHM_info.json to ./Dataset_500_EMPRESAS/PHM
# Moved PHM_income_statement.csv to ./Dataset_500_EMPRESAS/PHM
# Moved RVTY_info.json to ./Dataset_500_EMPRESAS/RVTY
# Moved RVTY_balance_sheet.csv to ./Dataset_500_EMPRESAS/RVTY
# Moved RVTY_cash_flow.csv to ./Dataset_500_EMPRESAS/RVTY
# Moved RVTY_historico.csv to ./Dataset_500_EMPRESAS/RVTY
# Moved RVTY_income_statement.csv to ./Dataset_500_EMPRESAS/RVTY
# Moved CVS_cash_flow.csv to ./Dataset_500_EMPRESAS/CVS
# Moved CVS_balance_sheet.csv to ./Dataset_500_EMPRESAS/CVS
# Moved CVS_income_statement.csv to ./Dataset_500_EMPRESAS/CVS
# Moved CVS_info.json to ./Dataset_500_EMPRESAS/CVS
# Moved CVS_historico.csv to ./Dataset_500_EMPRESAS/CVS
# Moved FITB_balance_sheet.csv to ./Dataset_500_EMPRESAS/FITB
# Moved FITB_historico.csv to ./Dataset_500_EMPRESAS/FITB
# Moved FITB_income_statement.csv to ./Dataset_500_EMPRESAS/FITB
# Moved FITB_info.json to ./Dataset_500_EMPRESAS/FITB
# Moved FITB_cash_flow.csv to ./Dataset_500_EMPRESAS/FITB
# Moved MDT_historico.csv to ./Dataset_500_EMPRESAS/MDT
# Moved MDT_info.json to ./Dataset_500_EMPRESAS/MDT
# Moved MDT_income_statement.csv to ./Dataset_500_EMPRESAS/MDT
# Moved MDT_cash_flow.csv to ./Dataset_500_EMPRESAS/MDT
# Moved MDT_balance_sheet.csv to ./Dataset_500_EMPRESAS/MDT
# Moved CAT_historico.csv to ./Dataset_500_EMPRESAS/CAT
# Moved CAT_info.json to ./Dataset_500_EMPRESAS/CAT
# Moved CAT_income_statement.csv to ./Dataset_500_EMPRESAS/CAT
# Moved CAT_cash_flow.csv to ./Dataset_500_EMPRESAS/CAT
# Moved CAT_balance_sheet.csv to ./Dataset_500_EMPRESAS/CAT
# Moved MPC_balance_sheet.csv to ./Dataset_500_EMPRESAS/MPC
# Moved MPC_info.json to ./Dataset_500_EMPRESAS/MPC
# Moved MPC_historico.csv to ./Dataset_500_EMPRESAS/MPC
# Moved MPC_income_statement.csv to ./Dataset_500_EMPRESAS/MPC
# Moved MPC_cash_flow.csv to ./Dataset_500_EMPRESAS/MPC
# Moved ALL_income_statement.csv to ./Dataset_500_EMPRESAS/ALL
# Moved ALL_cash_flow.csv to ./Dataset_500_EMPRESAS/ALL
# Moved ALL_info.json to ./Dataset_500_EMPRESAS/ALL
# Moved ALL_historico.csv to ./Dataset_500_EMPRESAS/ALL
# Moved ALL_balance_sheet.csv to ./Dataset_500_EMPRESAS/ALL
# Moved DOV_cash_flow.csv to ./Dataset_500_EMPRESAS/DOV
# Moved DOV_historico.csv to ./Dataset_500_EMPRESAS/DOV
# Moved DOV_balance_sheet.csv to ./Dataset_500_EMPRESAS/DOV
# Moved DOV_income_statement.csv to ./Dataset_500_EMPRESAS/DOV
# Moved DOV_info.json to ./Dataset_500_EMPRESAS/DOV
# Moved NOC_historico.csv to ./Dataset_500_EMPRESAS/NOC
# Moved NOC_balance_sheet.csv to ./Dataset_500_EMPRESAS/NOC
# Moved NOC_cash_flow.csv to ./Dataset_500_EMPRESAS/NOC
# Moved NOC_info.json to ./Dataset_500_EMPRESAS/NOC
# Moved NOC_income_statement.csv to ./Dataset_500_EMPRESAS/NOC
# Moved AXP_historico.csv to ./Dataset_500_EMPRESAS/AXP
# Moved AXP_info.json to ./Dataset_500_EMPRESAS/AXP
# Moved AXP_income_statement.csv to ./Dataset_500_EMPRESAS/AXP
# Moved AXP_balance_sheet.csv to ./Dataset_500_EMPRESAS/AXP
# Moved AXP_cash_flow.csv to ./Dataset_500_EMPRESAS/AXP
# Moved INTU_info.json to ./Dataset_500_EMPRESAS/INTU
# Moved INTU_cash_flow.csv to ./Dataset_500_EMPRESAS/INTU
# Moved INTU_income_statement.csv to ./Dataset_500_EMPRESAS/INTU
# Moved INTU_historico.csv to ./Dataset_500_EMPRESAS/INTU
# Moved INTU_balance_sheet.csv to ./Dataset_500_EMPRESAS/INTU
# Moved AMAT_income_statement.csv to ./Dataset_500_EMPRESAS/AMAT
# Moved AMAT_info.json to ./Dataset_500_EMPRESAS/AMAT
# Moved AMAT_cash_flow.csv to ./Dataset_500_EMPRESAS/AMAT
# Moved AMAT_balance_sheet.csv to ./Dataset_500_EMPRESAS/AMAT
# Moved AMAT_historico.csv to ./Dataset_500_EMPRESAS/AMAT
# Moved DLTR_balance_sheet.csv to ./Dataset_500_EMPRESAS/DLTR
# Moved DLTR_cash_flow.csv to ./Dataset_500_EMPRESAS/DLTR
# Moved DLTR_income_statement.csv to ./Dataset_500_EMPRESAS/DLTR
# Moved DLTR_historico.csv to ./Dataset_500_EMPRESAS/DLTR
# Moved DLTR_info.json to ./Dataset_500_EMPRESAS/DLTR
# Moved CRL_cash_flow.csv to ./Dataset_500_EMPRESAS/CRL
# Moved CRL_balance_sheet.csv to ./Dataset_500_EMPRESAS/CRL
# Moved CRL_info.json to ./Dataset_500_EMPRESAS/CRL
# Moved CRL_income_statement.csv to ./Dataset_500_EMPRESAS/CRL
# Moved CRL_historico.csv to ./Dataset_500_EMPRESAS/CRL
# Moved LNT_historico.csv to ./Dataset_500_EMPRESAS/LNT
# Moved LNT_info.json to ./Dataset_500_EMPRESAS/LNT
# Moved LNT_balance_sheet.csv to ./Dataset_500_EMPRESAS/LNT
# Moved LNT_cash_flow.csv to ./Dataset_500_EMPRESAS/LNT
# Moved LNT_income_statement.csv to ./Dataset_500_EMPRESAS/LNT
# Moved ALB_balance_sheet.csv to ./Dataset_500_EMPRESAS/ALB
# Moved ALB_cash_flow.csv to ./Dataset_500_EMPRESAS/ALB
# Moved ALB_info.json to ./Dataset_500_EMPRESAS/ALB
# Moved ALB_income_statement.csv to ./Dataset_500_EMPRESAS/ALB
# Moved ALB_historico.csv to ./Dataset_500_EMPRESAS/ALB
# Moved TAP_info.json to ./Dataset_500_EMPRESAS/TAP
# Moved TAP_cash_flow.csv to ./Dataset_500_EMPRESAS/TAP
# Moved TAP_historico.csv to ./Dataset_500_EMPRESAS/TAP
# Moved TAP_income_statement.csv to ./Dataset_500_EMPRESAS/TAP
# Moved TAP_balance_sheet.csv to ./Dataset_500_EMPRESAS/TAP
# Moved REG_info.json to ./Dataset_500_EMPRESAS/REG
# Moved REG_income_statement.csv to ./Dataset_500_EMPRESAS/REG
# Moved REG_historico.csv to ./Dataset_500_EMPRESAS/REG
# Moved REG_balance_sheet.csv to ./Dataset_500_EMPRESAS/REG
# Moved REG_cash_flow.csv to ./Dataset_500_EMPRESAS/REG
# Moved CPT_info.json to ./Dataset_500_EMPRESAS/CPT
# Moved CPT_cash_flow.csv to ./Dataset_500_EMPRESAS/CPT
# Moved CPT_income_statement.csv to ./Dataset_500_EMPRESAS/CPT
# Moved CPT_balance_sheet.csv to ./Dataset_500_EMPRESAS/CPT
# Moved CPT_historico.csv to ./Dataset_500_EMPRESAS/CPT
# Moved EPAM_income_statement.csv to ./Dataset_500_EMPRESAS/EPAM
# Moved EPAM_info.json to ./Dataset_500_EMPRESAS/EPAM
# Moved EPAM_historico.csv to ./Dataset_500_EMPRESAS/EPAM
# Moved EPAM_cash_flow.csv to ./Dataset_500_EMPRESAS/EPAM
# Moved EPAM_balance_sheet.csv to ./Dataset_500_EMPRESAS/EPAM
# Moved MKTX_historico.csv to ./Dataset_500_EMPRESAS/MKTX
# Moved MKTX_balance_sheet.csv to ./Dataset_500_EMPRESAS/MKTX
# Moved MKTX_income_statement.csv to ./Dataset_500_EMPRESAS/MKTX
# Moved MKTX_cash_flow.csv to ./Dataset_500_EMPRESAS/MKTX
# Moved MKTX_info.json to ./Dataset_500_EMPRESAS/MKTX
# Moved AWK_balance_sheet.csv to ./Dataset_500_EMPRESAS/AWK
# Moved AWK_historico.csv to ./Dataset_500_EMPRESAS/AWK
# Moved AWK_cash_flow.csv to ./Dataset_500_EMPRESAS/AWK
# Moved AWK_income_statement.csv to ./Dataset_500_EMPRESAS/AWK
# Moved AWK_info.json to ./Dataset_500_EMPRESAS/AWK
# Moved AMT_cash_flow.csv to ./Dataset_500_EMPRESAS/AMT
# Moved AMT_balance_sheet.csv to ./Dataset_500_EMPRESAS/AMT
# Moved AMT_info.json to ./Dataset_500_EMPRESAS/AMT
# Moved AMT_income_statement.csv to ./Dataset_500_EMPRESAS/AMT
# Moved AMT_historico.csv to ./Dataset_500_EMPRESAS/AMT
# Moved ABT_cash_flow.csv to ./Dataset_500_EMPRESAS/ABT
# Moved ABT_info.json to ./Dataset_500_EMPRESAS/ABT
# Moved ABT_income_statement.csv to ./Dataset_500_EMPRESAS/ABT
# Moved ABT_historico.csv to ./Dataset_500_EMPRESAS/ABT
# Moved ABT_balance_sheet.csv to ./Dataset_500_EMPRESAS/ABT
# Moved AIG_balance_sheet.csv to ./Dataset_500_EMPRESAS/AIG
# Moved AIG_historico.csv to ./Dataset_500_EMPRESAS/AIG
# Moved AIG_info.json to ./Dataset_500_EMPRESAS/AIG
# Moved AIG_income_statement.csv to ./Dataset_500_EMPRESAS/AIG
# Moved AIG_cash_flow.csv to ./Dataset_500_EMPRESAS/AIG
# Moved HWM_cash_flow.csv to ./Dataset_500_EMPRESAS/HWM
# Moved HWM_balance_sheet.csv to ./Dataset_500_EMPRESAS/HWM
# Moved HWM_income_statement.csv to ./Dataset_500_EMPRESAS/HWM
# Moved HWM_historico.csv to ./Dataset_500_EMPRESAS/HWM
# Moved HWM_info.json to ./Dataset_500_EMPRESAS/HWM
# Moved GOOG_historico.csv to ./Dataset_500_EMPRESAS/GOOG
# Moved GOOG_info.json to ./Dataset_500_EMPRESAS/GOOG
# Moved GOOG_income_statement.csv to ./Dataset_500_EMPRESAS/GOOG
# Moved GOOG_balance_sheet.csv to ./Dataset_500_EMPRESAS/GOOG
# Moved GOOG_cash_flow.csv to ./Dataset_500_EMPRESAS/GOOG
# Moved CTVA_historico.csv to ./Dataset_500_EMPRESAS/CTVA
# Moved CTVA_income_statement.csv to ./Dataset_500_EMPRESAS/CTVA
# Moved CTVA_info.json to ./Dataset_500_EMPRESAS/CTVA
# Moved CTVA_balance_sheet.csv to ./Dataset_500_EMPRESAS/CTVA
# Moved CTVA_cash_flow.csv to ./Dataset_500_EMPRESAS/CTVA
# Moved BF-B_balance_sheet.csv to ./Dataset_500_EMPRESAS/BF-B
# Moved BF-B_info.json to ./Dataset_500_EMPRESAS/BF-B
# Moved BF-B_cash_flow.csv to ./Dataset_500_EMPRESAS/BF-B
# Moved BF-B_income_statement.csv to ./Dataset_500_EMPRESAS/BF-B
# Moved BF-B_historico.csv to ./Dataset_500_EMPRESAS/BF-B
# Moved HD_income_statement.csv to ./Dataset_500_EMPRESAS/HD
# Moved HD_balance_sheet.csv to ./Dataset_500_EMPRESAS/HD
# Moved HD_historico.csv to ./Dataset_500_EMPRESAS/HD
# Moved HD_info.json to ./Dataset_500_EMPRESAS/HD
# Moved HD_cash_flow.csv to ./Dataset_500_EMPRESAS/HD
# Moved TTWO_balance_sheet.csv to ./Dataset_500_EMPRESAS/TTWO
# Moved TTWO_income_statement.csv to ./Dataset_500_EMPRESAS/TTWO
# Moved TTWO_cash_flow.csv to ./Dataset_500_EMPRESAS/TTWO
# Moved TTWO_info.json to ./Dataset_500_EMPRESAS/TTWO
# Moved TTWO_historico.csv to ./Dataset_500_EMPRESAS/TTWO
# Moved CDNS_historico.csv to ./Dataset_500_EMPRESAS/CDNS
# Moved CDNS_info.json to ./Dataset_500_EMPRESAS/CDNS
# Moved CDNS_income_statement.csv to ./Dataset_500_EMPRESAS/CDNS
# Moved CDNS_cash_flow.csv to ./Dataset_500_EMPRESAS/CDNS
# Moved CDNS_balance_sheet.csv to ./Dataset_500_EMPRESAS/CDNS
# Moved WM_cash_flow.csv to ./Dataset_500_EMPRESAS/WM
# Moved WM_balance_sheet.csv to ./Dataset_500_EMPRESAS/WM
# Moved WM_income_statement.csv to ./Dataset_500_EMPRESAS/WM
# Moved WM_info.json to ./Dataset_500_EMPRESAS/WM
# Moved WM_historico.csv to ./Dataset_500_EMPRESAS/WM
# Moved NTRS_income_statement.csv to ./Dataset_500_EMPRESAS/NTRS
# ...
# Moved MSCI_info.json to ./Dataset_500_EMPRESAS/MSCI
# Moved MSCI_income_statement.csv to ./Dataset_500_EMPRESAS/MSCI
# Moved MSCI_historico.csv to ./Dataset_500_EMPRESAS/MSCI
# Moved MSCI_balance_sheet.csv to ./Dataset_500_EMPRESAS/MSCI
# Moved MSCI_cash_flow.csv to ./Dataset_500_EMPRESAS/MSCI
# Moved SLB_cash_flow.csv to ./Dataset_500_EMPRESAS/SLB
# Moved SLB_balance_sheet.csv to ./Dataset_500_EMPRESAS/SLB
# Moved SLB_income_statement.csv to ./Dataset_500_EMPRESAS/SLB
# Moved SLB_info.json to ./Dataset_500_EMPRESAS/SLB
# Moved SLB_historico.csv to ./Dataset_500_EMPRESAS/SLB
# Moved MAA_balance_sheet.csv to ./Dataset_500_EMPRESAS/MAA
# Moved MAA_income_statement.csv to ./Dataset_500_EMPRESAS/MAA
# Moved MAA_historico.csv to ./Dataset_500_EMPRESAS/MAA
# Moved MAA_info.json to ./Dataset_500_EMPRESAS/MAA
# Moved MAA_cash_flow.csv to ./Dataset_500_EMPRESAS/MAA
# Moved ITW_balance_sheet.csv to ./Dataset_500_EMPRESAS/ITW
# Moved ITW_info.json to ./Dataset_500_EMPRESAS/ITW
# Moved ITW_historico.csv to ./Dataset_500_EMPRESAS/ITW
# Moved ITW_cash_flow.csv to ./Dataset_500_EMPRESAS/ITW
# Moved ITW_income_statement.csv to ./Dataset_500_EMPRESAS/ITW
# Moved FIS_info.json to ./Dataset_500_EMPRESAS/FIS
# Moved FIS_cash_flow.csv to ./Dataset_500_EMPRESAS/FIS
# Moved FIS_income_statement.csv to ./Dataset_500_EMPRESAS/FIS
# Moved FIS_historico.csv to ./Dataset_500_EMPRESAS/FIS
# Moved FIS_balance_sheet.csv to ./Dataset_500_EMPRESAS/FIS
# Moved WDC_info.json to ./Dataset_500_EMPRESAS/WDC
# Moved WDC_balance_sheet.csv to ./Dataset_500_EMPRESAS/WDC
# Moved WDC_cash_flow.csv to ./Dataset_500_EMPRESAS/WDC
# Moved WDC_historico.csv to ./Dataset_500_EMPRESAS/WDC
# Moved WDC_income_statement.csv to ./Dataset_500_EMPRESAS/WDC
# Moved L_balance_sheet.csv to ./Dataset_500_EMPRESAS/L
# Moved L_cash_flow.csv to ./Dataset_500_EMPRESAS/L
# Moved L_historico.csv to ./Dataset_500_EMPRESAS/L
# Moved L_info.json to ./Dataset_500_EMPRESAS/L
# Moved L_income_statement.csv to ./Dataset_500_EMPRESAS/L
# Moved HAL_cash_flow.csv to ./Dataset_500_EMPRESAS/HAL
# Moved HAL_historico.csv to ./Dataset_500_EMPRESAS/HAL
# Moved HAL_info.json to ./Dataset_500_EMPRESAS/HAL
# Moved HAL_income_statement.csv to ./Dataset_500_EMPRESAS/HAL
# Moved HAL_balance_sheet.csv to ./Dataset_500_EMPRESAS/HAL
# Moved EXE_income_statement.csv to ./Dataset_500_EMPRESAS/EXE
# Moved EXE_balance_sheet.csv to ./Dataset_500_EMPRESAS/EXE
# Moved EXE_cash_flow.csv to ./Dataset_500_EMPRESAS/EXE
# Moved EXE_historico.csv to ./Dataset_500_EMPRESAS/EXE
# Moved EXE_info.json to ./Dataset_500_EMPRESAS/EXE
# Moved KMB_historico.csv to ./Dataset_500_EMPRESAS/KMB
# Moved KMB_info.json to ./Dataset_500_EMPRESAS/KMB
# Moved KMB_balance_sheet.csv to ./Dataset_500_EMPRESAS/KMB
# Moved KMB_cash_flow.csv to ./Dataset_500_EMPRESAS/KMB
# Moved KMB_income_statement.csv to ./Dataset_500_EMPRESAS/KMB
# Moved APTV_income_statement.csv to ./Dataset_500_EMPRESAS/APTV
# Moved APTV_cash_flow.csv to ./Dataset_500_EMPRESAS/APTV
# Moved APTV_balance_sheet.csv to ./Dataset_500_EMPRESAS/APTV
# Moved APTV_historico.csv to ./Dataset_500_EMPRESAS/APTV
# Moved APTV_info.json to ./Dataset_500_EMPRESAS/APTV
# Moved HPE_income_statement.csv to ./Dataset_500_EMPRESAS/HPE
# Moved HPE_historico.csv to ./Dataset_500_EMPRESAS/HPE
# Moved HPE_balance_sheet.csv to ./Dataset_500_EMPRESAS/HPE
# Moved HPE_info.json to ./Dataset_500_EMPRESAS/HPE
# Moved HPE_cash_flow.csv to ./Dataset_500_EMPRESAS/HPE
# Moved ADSK_historico.csv to ./Dataset_500_EMPRESAS/ADSK
# Moved ADSK_cash_flow.csv to ./Dataset_500_EMPRESAS/ADSK
# Moved ADSK_info.json to ./Dataset_500_EMPRESAS/ADSK
# Moved ADSK_balance_sheet.csv to ./Dataset_500_EMPRESAS/ADSK
# Moved ADSK_income_statement.csv to ./Dataset_500_EMPRESAS/ADSK
# Moved MSI_income_statement.csv to ./Dataset_500_EMPRESAS/MSI
# Moved MSI_historico.csv to ./Dataset_500_EMPRESAS/MSI
# Moved MSI_balance_sheet.csv to ./Dataset_500_EMPRESAS/MSI
# Moved MSI_cash_flow.csv to ./Dataset_500_EMPRESAS/MSI
# Moved MSI_info.json to ./Dataset_500_EMPRESAS/MSI
# Moved CBRE_cash_flow.csv to ./Dataset_500_EMPRESAS/CBRE
# Moved CBRE_info.json to ./Dataset_500_EMPRESAS/CBRE
# Moved CBRE_balance_sheet.csv to ./Dataset_500_EMPRESAS/CBRE
# Moved CBRE_income_statement.csv to ./Dataset_500_EMPRESAS/CBRE
# Moved CBRE_historico.csv to ./Dataset_500_EMPRESAS/CBRE
# Moved NEM_info.json to ./Dataset_500_EMPRESAS/NEM
# Moved NEM_balance_sheet.csv to ./Dataset_500_EMPRESAS/NEM
# Moved NEM_historico.csv to ./Dataset_500_EMPRESAS/NEM
# Moved NEM_cash_flow.csv to ./Dataset_500_EMPRESAS/NEM
# Moved NEM_income_statement.csv to ./Dataset_500_EMPRESAS/NEM
# Moved DVA_cash_flow.csv to ./Dataset_500_EMPRESAS/DVA
# Moved DVA_info.json to ./Dataset_500_EMPRESAS/DVA
# Moved DVA_balance_sheet.csv to ./Dataset_500_EMPRESAS/DVA
# Moved DVA_income_statement.csv to ./Dataset_500_EMPRESAS/DVA
# Moved DVA_historico.csv to ./Dataset_500_EMPRESAS/DVA
# Moved WYNN_cash_flow.csv to ./Dataset_500_EMPRESAS/WYNN
# Moved WYNN_income_statement.csv to ./Dataset_500_EMPRESAS/WYNN
# Moved WYNN_balance_sheet.csv to ./Dataset_500_EMPRESAS/WYNN
# Moved WYNN_historico.csv to ./Dataset_500_EMPRESAS/WYNN
# Moved WYNN_info.json to ./Dataset_500_EMPRESAS/WYNN
# Moved MCK_income_statement.csv to ./Dataset_500_EMPRESAS/MCK
# Moved MCK_historico.csv to ./Dataset_500_EMPRESAS/MCK
# Moved MCK_balance_sheet.csv to ./Dataset_500_EMPRESAS/MCK
# Moved MCK_info.json to ./Dataset_500_EMPRESAS/MCK
# Moved MCK_cash_flow.csv to ./Dataset_500_EMPRESAS/MCK
# Moved EIX_cash_flow.csv to ./Dataset_500_EMPRESAS/EIX
# Moved EIX_balance_sheet.csv to ./Dataset_500_EMPRESAS/EIX
# Moved EIX_info.json to ./Dataset_500_EMPRESAS/EIX
# Moved EIX_historico.csv to ./Dataset_500_EMPRESAS/EIX
# Moved EIX_income_statement.csv to ./Dataset_500_EMPRESAS/EIX
# Moved UDR_historico.csv to ./Dataset_500_EMPRESAS/UDR
# Moved UDR_info.json to ./Dataset_500_EMPRESAS/UDR
# Moved UDR_cash_flow.csv to ./Dataset_500_EMPRESAS/UDR
# Moved UDR_income_statement.csv to ./Dataset_500_EMPRESAS/UDR
# Moved UDR_balance_sheet.csv to ./Dataset_500_EMPRESAS/UDR
# Moved CCL_info.json to ./Dataset_500_EMPRESAS/CCL
# Moved CCL_balance_sheet.csv to ./Dataset_500_EMPRESAS/CCL
# Moved CCL_historico.csv to ./Dataset_500_EMPRESAS/CCL
# Moved CCL_cash_flow.csv to ./Dataset_500_EMPRESAS/CCL
# Moved CCL_income_statement.csv to ./Dataset_500_EMPRESAS/CCL
# Moved HRL_balance_sheet.csv to ./Dataset_500_EMPRESAS/HRL
# Moved HRL_historico.csv to ./Dataset_500_EMPRESAS/HRL
# Moved HRL_cash_flow.csv to ./Dataset_500_EMPRESAS/HRL
# Moved HRL_info.json to ./Dataset_500_EMPRESAS/HRL
# Moved HRL_income_statement.csv to ./Dataset_500_EMPRESAS/HRL
# Moved MGM_info.json to ./Dataset_500_EMPRESAS/MGM
# Moved MGM_cash_flow.csv to ./Dataset_500_EMPRESAS/MGM
# Moved MGM_balance_sheet.csv to ./Dataset_500_EMPRESAS/MGM
# Moved MGM_historico.csv to ./Dataset_500_EMPRESAS/MGM
# Moved MGM_income_statement.csv to ./Dataset_500_EMPRESAS/MGM
# Moved BAX_balance_sheet.csv to ./Dataset_500_EMPRESAS/BAX
# Moved BAX_cash_flow.csv to ./Dataset_500_EMPRESAS/BAX
# Moved BAX_historico.csv to ./Dataset_500_EMPRESAS/BAX
# Moved BAX_info.json to ./Dataset_500_EMPRESAS/BAX
# Moved BAX_income_statement.csv to ./Dataset_500_EMPRESAS/BAX
# Moved VTRS_historico.csv to ./Dataset_500_EMPRESAS/VTRS
# Moved VTRS_cash_flow.csv to ./Dataset_500_EMPRESAS/VTRS
# Moved VTRS_income_statement.csv to ./Dataset_500_EMPRESAS/VTRS
# Moved VTRS_balance_sheet.csv to ./Dataset_500_EMPRESAS/VTRS
# Moved VTRS_info.json to ./Dataset_500_EMPRESAS/VTRS
# Moved KDP_historico.csv to ./Dataset_500_EMPRESAS/KDP
# Moved KDP_info.json to ./Dataset_500_EMPRESAS/KDP
# Moved KDP_income_statement.csv to ./Dataset_500_EMPRESAS/KDP
# Moved KDP_cash_flow.csv to ./Dataset_500_EMPRESAS/KDP
# Moved KDP_balance_sheet.csv to ./Dataset_500_EMPRESAS/KDP
# Moved DASH_cash_flow.csv to ./Dataset_500_EMPRESAS/DASH
# Moved DASH_info.json to ./Dataset_500_EMPRESAS/DASH
# Moved DASH_historico.csv to ./Dataset_500_EMPRESAS/DASH
# Moved DASH_income_statement.csv to ./Dataset_500_EMPRESAS/DASH
# Moved DASH_balance_sheet.csv to ./Dataset_500_EMPRESAS/DASH
# Moved APA_balance_sheet.csv to ./Dataset_500_EMPRESAS/APA
# Moved APA_historico.csv to ./Dataset_500_EMPRESAS/APA
# Moved APA_income_statement.csv to ./Dataset_500_EMPRESAS/APA
# Moved APA_info.json to ./Dataset_500_EMPRESAS/APA
# Moved APA_cash_flow.csv to ./Dataset_500_EMPRESAS/APA
# Moved CME_historico.csv to ./Dataset_500_EMPRESAS/CME
# Moved CME_income_statement.csv to ./Dataset_500_EMPRESAS/CME
# Moved CME_info.json to ./Dataset_500_EMPRESAS/CME
# Moved CME_balance_sheet.csv to ./Dataset_500_EMPRESAS/CME
# Moved CME_cash_flow.csv to ./Dataset_500_EMPRESAS/CME
# Moved DECK_cash_flow.csv to ./Dataset_500_EMPRESAS/DECK
# Moved DECK_balance_sheet.csv to ./Dataset_500_EMPRESAS/DECK
# Moved DECK_info.json to ./Dataset_500_EMPRESAS/DECK
# Moved DECK_income_statement.csv to ./Dataset_500_EMPRESAS/DECK
# Moved DECK_historico.csv to ./Dataset_500_EMPRESAS/DECK
# Moved AKAM_info.json to ./Dataset_500_EMPRESAS/AKAM
# Moved AKAM_historico.csv to ./Dataset_500_EMPRESAS/AKAM
# Moved AKAM_cash_flow.csv to ./Dataset_500_EMPRESAS/AKAM
# Moved AKAM_income_statement.csv to ./Dataset_500_EMPRESAS/AKAM
# Moved AKAM_balance_sheet.csv to ./Dataset_500_EMPRESAS/AKAM
# Moved NOW_cash_flow.csv to ./Dataset_500_EMPRESAS/NOW
# Moved NOW_historico.csv to ./Dataset_500_EMPRESAS/NOW
# Moved NOW_balance_sheet.csv to ./Dataset_500_EMPRESAS/NOW
# Moved NOW_info.json to ./Dataset_500_EMPRESAS/NOW
# Moved NOW_income_statement.csv to ./Dataset_500_EMPRESAS/NOW
# Moved AMZN_cash_flow.csv to ./Dataset_500_EMPRESAS/AMZN
# Moved AMZN_balance_sheet.csv to ./Dataset_500_EMPRESAS/AMZN
# Moved AMZN_income_statement.csv to ./Dataset_500_EMPRESAS/AMZN
# Moved AMZN_historico.csv to ./Dataset_500_EMPRESAS/AMZN
# Moved AMZN_info.json to ./Dataset_500_EMPRESAS/AMZN
# Moved CHD_info.json to ./Dataset_500_EMPRESAS/CHD
# Moved CHD_cash_flow.csv to ./Dataset_500_EMPRESAS/CHD
# Moved CHD_income_statement.csv to ./Dataset_500_EMPRESAS/CHD
# Moved CHD_historico.csv to ./Dataset_500_EMPRESAS/CHD
# Moved CHD_balance_sheet.csv to ./Dataset_500_EMPRESAS/CHD
# Moved UBER_balance_sheet.csv to ./Dataset_500_EMPRESAS/UBER
# Moved UBER_historico.csv to ./Dataset_500_EMPRESAS/UBER
# Moved UBER_income_statement.csv to ./Dataset_500_EMPRESAS/UBER
# Moved UBER_info.json to ./Dataset_500_EMPRESAS/UBER
# Moved UBER_cash_flow.csv to ./Dataset_500_EMPRESAS/UBER
# Moved PWR_balance_sheet.csv to ./Dataset_500_EMPRESAS/PWR
# Moved PWR_historico.csv to ./Dataset_500_EMPRESAS/PWR
# Moved PWR_info.json to ./Dataset_500_EMPRESAS/PWR
# Moved PWR_cash_flow.csv to ./Dataset_500_EMPRESAS/PWR
# Moved PWR_income_statement.csv to ./Dataset_500_EMPRESAS/PWR
# Moved PEG_income_statement.csv to ./Dataset_500_EMPRESAS/PEG
# Moved PEG_cash_flow.csv to ./Dataset_500_EMPRESAS/PEG
# Moved PEG_historico.csv to ./Dataset_500_EMPRESAS/PEG
# Moved PEG_balance_sheet.csv to ./Dataset_500_EMPRESAS/PEG
# Moved PEG_info.json to ./Dataset_500_EMPRESAS/PEG
# Moved LDOS_balance_sheet.csv to ./Dataset_500_EMPRESAS/LDOS
# Moved LDOS_income_statement.csv to ./Dataset_500_EMPRESAS/LDOS
# Moved LDOS_historico.csv to ./Dataset_500_EMPRESAS/LDOS
# Moved LDOS_cash_flow.csv to ./Dataset_500_EMPRESAS/LDOS
# Moved LDOS_info.json to ./Dataset_500_EMPRESAS/LDOS
# Moved TROW_info.json to ./Dataset_500_EMPRESAS/TROW
# Moved TROW_historico.csv to ./Dataset_500_EMPRESAS/TROW
# Moved TROW_income_statement.csv to ./Dataset_500_EMPRESAS/TROW
# Moved TROW_balance_sheet.csv to ./Dataset_500_EMPRESAS/TROW
# Moved TROW_cash_flow.csv to ./Dataset_500_EMPRESAS/TROW
# Moved CB_cash_flow.csv to ./Dataset_500_EMPRESAS/CB
# Moved CB_balance_sheet.csv to ./Dataset_500_EMPRESAS/CB
# Moved CB_info.json to ./Dataset_500_EMPRESAS/CB
# Moved CB_income_statement.csv to ./Dataset_500_EMPRESAS/CB
# Moved CB_historico.csv to ./Dataset_500_EMPRESAS/CB
# Moved MNST_historico.csv to ./Dataset_500_EMPRESAS/MNST
# Moved MNST_balance_sheet.csv to ./Dataset_500_EMPRESAS/MNST
# Moved MNST_income_statement.csv to ./Dataset_500_EMPRESAS/MNST
# Moved MNST_info.json to ./Dataset_500_EMPRESAS/MNST
# Moved MNST_cash_flow.csv to ./Dataset_500_EMPRESAS/MNST
# Moved CRWD_balance_sheet.csv to ./Dataset_500_EMPRESAS/CRWD
# Moved CRWD_cash_flow.csv to ./Dataset_500_EMPRESAS/CRWD
# Moved CRWD_info.json to ./Dataset_500_EMPRESAS/CRWD
# Moved CRWD_historico.csv to ./Dataset_500_EMPRESAS/CRWD
# Moved CRWD_income_statement.csv to ./Dataset_500_EMPRESAS/CRWD
# Moved CSCO_income_statement.csv to ./Dataset_500_EMPRESAS/CSCO
# Moved CSCO_cash_flow.csv to ./Dataset_500_EMPRESAS/CSCO
# Moved CSCO_balance_sheet.csv to ./Dataset_500_EMPRESAS/CSCO
# Moved CSCO_historico.csv to ./Dataset_500_EMPRESAS/CSCO
# Moved CSCO_info.json to ./Dataset_500_EMPRESAS/CSCO
# Moved KO_cash_flow.csv to ./Dataset_500_EMPRESAS/KO
# Moved KO_info.json to ./Dataset_500_EMPRESAS/KO
# Moved KO_historico.csv to ./Dataset_500_EMPRESAS/KO
# Moved KO_balance_sheet.csv to ./Dataset_500_EMPRESAS/KO
# Moved KO_income_statement.csv to ./Dataset_500_EMPRESAS/KO
# Moved BMY_historico.csv to ./Dataset_500_EMPRESAS/BMY
# Moved BMY_info.json to ./Dataset_500_EMPRESAS/BMY
# Moved BMY_cash_flow.csv to ./Dataset_500_EMPRESAS/BMY
# Moved BMY_balance_sheet.csv to ./Dataset_500_EMPRESAS/BMY
# Moved BMY_income_statement.csv to ./Dataset_500_EMPRESAS/BMY
# Moved ICE_cash_flow.csv to ./Dataset_500_EMPRESAS/ICE
# Moved ICE_income_statement.csv to ./Dataset_500_EMPRESAS/ICE
# Moved ICE_balance_sheet.csv to ./Dataset_500_EMPRESAS/ICE
# Moved ICE_info.json to ./Dataset_500_EMPRESAS/ICE
# Moved ICE_historico.csv to ./Dataset_500_EMPRESAS/ICE
# Moved CRM_historico.csv to ./Dataset_500_EMPRESAS/CRM
# Moved CRM_info.json to ./Dataset_500_EMPRESAS/CRM
# Moved CRM_balance_sheet.csv to ./Dataset_500_EMPRESAS/CRM
# Moved CRM_income_statement.csv to ./Dataset_500_EMPRESAS/CRM
# Moved CRM_cash_flow.csv to ./Dataset_500_EMPRESAS/CRM
# Moved CTSH_historico.csv to ./Dataset_500_EMPRESAS/CTSH
# Moved CTSH_income_statement.csv to ./Dataset_500_EMPRESAS/CTSH
# Moved CTSH_balance_sheet.csv to ./Dataset_500_EMPRESAS/CTSH
# Moved CTSH_cash_flow.csv to ./Dataset_500_EMPRESAS/CTSH
# Moved CTSH_info.json to ./Dataset_500_EMPRESAS/CTSH
# Moved ERIE_info.json to ./Dataset_500_EMPRESAS/ERIE
# Moved ERIE_historico.csv to ./Dataset_500_EMPRESAS/ERIE
# Moved ERIE_balance_sheet.csv to ./Dataset_500_EMPRESAS/ERIE
# Moved ERIE_cash_flow.csv to ./Dataset_500_EMPRESAS/ERIE
# Moved ERIE_income_statement.csv to ./Dataset_500_EMPRESAS/ERIE
# Moved DXCM_balance_sheet.csv to ./Dataset_500_EMPRESAS/DXCM
# Moved DXCM_historico.csv to ./Dataset_500_EMPRESAS/DXCM
# Moved DXCM_info.json to ./Dataset_500_EMPRESAS/DXCM
# Moved DXCM_income_statement.csv to ./Dataset_500_EMPRESAS/DXCM
# Moved DXCM_cash_flow.csv to ./Dataset_500_EMPRESAS/DXCM
# Moved WMB_income_statement.csv to ./Dataset_500_EMPRESAS/WMB
# Moved WMB_historico.csv to ./Dataset_500_EMPRESAS/WMB
# Moved WMB_cash_flow.csv to ./Dataset_500_EMPRESAS/WMB
# Moved WMB_balance_sheet.csv to ./Dataset_500_EMPRESAS/WMB
# Moved WMB_info.json to ./Dataset_500_EMPRESAS/WMB
# Moved MA_cash_flow.csv to ./Dataset_500_EMPRESAS/MA
# Moved MA_balance_sheet.csv to ./Dataset_500_EMPRESAS/MA
# Moved MA_info.json to ./Dataset_500_EMPRESAS/MA
# Moved MA_historico.csv to ./Dataset_500_EMPRESAS/MA
# Moved MA_income_statement.csv to ./Dataset_500_EMPRESAS/MA
# Moved BRK-B_income_statement.csv to ./Dataset_500_EMPRESAS/BRK-B
# Moved BRK-B_cash_flow.csv to ./Dataset_500_EMPRESAS/BRK-B
# Moved BRK-B_info.json to ./Dataset_500_EMPRESAS/BRK-B
# Moved BRK-B_balance_sheet.csv to ./Dataset_500_EMPRESAS/BRK-B
# Moved BRK-B_historico.csv to ./Dataset_500_EMPRESAS/BRK-B
# Moved VST_income_statement.csv to ./Dataset_500_EMPRESAS/VST
# Moved VST_cash_flow.csv to ./Dataset_500_EMPRESAS/VST
# Moved VST_historico.csv to ./Dataset_500_EMPRESAS/VST
# Moved VST_info.json to ./Dataset_500_EMPRESAS/VST
# Moved VST_balance_sheet.csv to ./Dataset_500_EMPRESAS/VST
# Moved NKE_cash_flow.csv to ./Dataset_500_EMPRESAS/NKE
# Moved NKE_info.json to ./Dataset_500_EMPRESAS/NKE
# Moved NKE_income_statement.csv to ./Dataset_500_EMPRESAS/NKE
# Moved NKE_balance_sheet.csv to ./Dataset_500_EMPRESAS/NKE
# Moved NKE_historico.csv to ./Dataset_500_EMPRESAS/NKE
# Moved VZ_historico.csv to ./Dataset_500_EMPRESAS/VZ
# Moved VZ_info.json to ./Dataset_500_EMPRESAS/VZ
# Moved VZ_balance_sheet.csv to ./Dataset_500_EMPRESAS/VZ
# Moved VZ_cash_flow.csv to ./Dataset_500_EMPRESAS/VZ
# Moved VZ_income_statement.csv to ./Dataset_500_EMPRESAS/VZ
# Organización completada.

# %%
import pandas as pd
import os
import json

def procesar_ticker(ticker, base_path):
    # Cargar datos históricos
    hist_path = os.path.join(base_path, ticker, f"{ticker}_historico.csv")
    df_hist = pd.read_csv(hist_path, parse_dates=['Date'], index_col='Date')
    
    # Cargar datos financieros
    financial_dfs = []
    for tipo in ['cash_flow', 'balance_sheet', 'income_statement']:
        path = os.path.join(base_path, ticker, f"{ticker}_{tipo}.csv")
        if not os.path.exists(path):
            print(f"Advertencia: No existe {path}")
            continue
        df = pd.read_csv(path, index_col=0)
        df = df.T  # Transponer para que las fechas sean el índice
        df.index = pd.to_datetime(df.index)
        financial_dfs.append(df)
    
    if not financial_dfs:
        print(f"No hay datos financieros para {ticker}")
        return
    
    # Combinar datos financieros
    df_financial = pd.concat(financial_dfs, axis=1)
    
    # Crear índice diario covering el rango de fechas históricas
    start_date = df_hist.index.min()
    end_date = df_hist.index.max()
    idx_diario = pd.date_range(start=start_date, end=end_date, freq='D')
    
    # Reindexar datos financieros al índice diario
    df_financial_diario = df_financial.reindex(idx_diario)
    
    # Forward fill para propagar valores
    df_financial_diario = df_financial_diario.ffill()
    
    # Rellenar con 0 las fechas anteriores al primer reporte financiero
    if not df_financial.empty:
        first_financial_date = df_financial.index.min()
        mask = idx_diario < first_financial_date
        df_financial_diario.loc[mask] = 0
    
    # Combinar con datos históricos
    df_combinado = df_hist.join(df_financial_diario, how='left')
    
    # Cargar sectorKey desde info.json
    info_path = os.path.join(base_path, ticker, f"{ticker}_info.json")
    with open(info_path, 'r') as f:
        info_data = json.load(f)
    sector_key = info_data.get('sectorKey', '')
    
    # Añadir sectorKey como columna
    df_combinado['sectorKey'] = sector_key
    
    # Guardar resultado
    output_path = os.path.join(base_path, f"{ticker}_completo.csv")
    df_combinado.to_csv(output_path, index_label='Date')
    print(f"Guardado: {output_path}")

# Procesar todos los tickers
base_path = './Dataset_500_EMPRESAS'  # Cambia esto si es necesario
tickers = [d for d in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, d))]

for ticker in tickers:
    try:
        procesar_ticker(ticker, base_path)
    except Exception as e:
        print(f"Error procesando {ticker}: {str(e)}")
# Out:
# Guardado: ./Dataset_500_EMPRESAS/CTAS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/WELL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/VZ_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AMZN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CNP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/RCL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CAT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TFC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AAPL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/BF-B_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PANW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/KHC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TEL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CMCSA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/GRMN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ANET_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/BRO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CAH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/SW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/SOLV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TROW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PODD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/FSLR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PFE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/REG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/APTV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CDW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MAR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/VRSN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/FITB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/KMI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/UBER_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/SPGI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ALLE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/SYK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MMC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MPWR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DXCM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PEP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/FRT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/SNPS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PLD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/GOOG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MMM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/EMN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/NXPI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PCG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AMT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ADI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MAA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/WSM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/HWM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MAS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/FTV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CAG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MGM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CNC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/VLO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/UPS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PLTR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CME_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/NWS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/EMR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/OKE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/SYY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/GILD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/SNA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PTC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AXON_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/WMT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/HUBB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ULTA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CVX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/NCLH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/UHS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/GPN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DLR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CPT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TXN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/KLAC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/INTC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/BK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/NI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/LII_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TTWO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/HCA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/GS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TMUS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/BLK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CDNS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/LOW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/LIN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/HII_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CZR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DFS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PRU_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/BX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/KVUE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CTSH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/SHW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MCHP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/VTR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/HIG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MU_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TXT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ACGL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/APD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/HD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/FIS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/IPG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/NDSN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/UNP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AMAT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/LLY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/WBD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/FOX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/JNPR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ERIE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/NTAP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/FICO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MSI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AKAM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/SBAC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/WAB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/REGN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/RSG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/IR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ENPH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AWK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/EXR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/HAL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MRNA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/IQV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/VST_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/EW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/LMT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TYL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PPL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/EQT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ANSS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/EPAM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/SLB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CRL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CSGP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/EL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/JKHY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/LKQ_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/WFC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CRWD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/WYNN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PSX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MRK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/JNJ_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/INVH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/QCOM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/LNT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/BAC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CF_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/BRK-B_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/IT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DHI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/LW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/LHX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/FE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/BBY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/IRM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TPL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TSLA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DGX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CRM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/EQR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/HBAN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/COST_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/FDS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ED_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/BAX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DHR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/GOOGL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/HSIC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/WEC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ALB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MOS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/WM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ICE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/STX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/LVS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/STLD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CCL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TMO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AIZ_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PHM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MSFT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TGT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ALL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/META_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/BSX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/FAST_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ELV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/SWK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MOH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ABBV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AFL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/OTIS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MCD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/RMD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AJG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/WTW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/IFF_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PGR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/HPE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CEG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/EFX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MET_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/COR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/EQIX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/LYB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TDG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/NFLX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/VTRS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PNR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/KEY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ACN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CINF_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/COO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AEP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CHRW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/COF_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/LYV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/VMC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ALGN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/HSY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/T_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/HPQ_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/GEN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ORCL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CBRE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CHTR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DUK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TAP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/NUE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/FFIV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MCK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/A_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DELL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AIG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/EBAY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DPZ_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/WY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/F_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/NTRS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/O_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/RF_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CFG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/STE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AEE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PYPL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DRI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/NRG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CMG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/IBM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/WST_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ADP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PEG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MKC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CMI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AMD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MHK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/KDP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/HRL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/INCY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/BXP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/XOM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/USB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/SO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/KMX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/LRCX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CHD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/FOXA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DTE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/BLDR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/NDAQ_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/JBHT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/SMCI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CPAY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/VRSK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PFG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TER_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ROP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/KKR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AME_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/XEL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/RJF_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/KMB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/SPG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DLTR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TJX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ROL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/SBUX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/YUM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CMS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ROK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MDLZ_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PCAR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MDT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/EVRG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/SYF_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ABT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ADM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AMP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/OMC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/WDAY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/NEE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/NOW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CSX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CARR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AZO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PAYC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MPC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/KR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/FCX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DOW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/UDR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/WMB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/RTX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TRV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/BALL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/GPC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/HON_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/WBA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/BA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/APA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/FTNT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/GE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ESS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/HLT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PAYX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/INTU_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CPB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/BEN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/APO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/WDC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/BIIB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/APH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/GL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/VICI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/NVDA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/JCI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/NEM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AMGN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DOV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CTVA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/BG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/UAL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PWR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/UNH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ZTS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/HES_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/LEN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AVB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/LDOS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/GM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DIS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/WAT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/NOC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/IDXX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DASH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CSCO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MTCH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CVS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/GD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AVY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DOC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/BR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/GDDY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/KO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/IVZ_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PARA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AXP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/FI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/KEYS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AVGO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ISRG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MTB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/VLTO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ARE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/HAS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/EA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CTRA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ODFL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/EXC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/FDX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/NWSA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CBOE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MNST_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ZBRA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TPR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ES_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/FANG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ADSK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/SJM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AMCR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ETN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/XYL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/BMY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/EXE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ITW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DAL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TSN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CPRT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MTD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TSCO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/EG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DAY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/NKE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/LH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/GWW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PSA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/BDX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/BKNG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ETR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ATO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PPG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/IP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/SWKS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/JBL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/BKR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/LULU_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ON_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/OXY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/URI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/HOLX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TECH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ADBE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/J_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/POOL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/EIX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MLM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/C_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TRMB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/D_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TRGP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DVA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/GNRC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/IEX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ABNB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/V_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/SRE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AON_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MKTX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/EXPD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/VRTX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/LUV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PNW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/RL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/GIS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ECL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ZBH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/EOG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/KIM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CLX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MCO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/COP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ORLY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DECK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/JPM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/GEV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/ROST_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/K_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/DVN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/RVTY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PNC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/WRB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AOS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/L_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TKO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/TDY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/NSC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/AES_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/PKG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/EXPE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/HUM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/HST_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/NVR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/STT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/CCI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/GEHC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/SCHW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/STZ_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/MSCI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS/GLW_completo.csv

# %%
import pandas as pd
import os
import numpy as np

def limpiar_datos(ticker, input_dir, output_dir):
    # Leer el archivo CSV
    input_path = os.path.join(input_dir, f"{ticker}_completo.csv")
    df = pd.read_csv(input_path)
    
    # Convertir la columna 'Free Cash Flow' a numérico, manejando errores
    df['Free Cash Flow'] = pd.to_numeric(df['Free Cash Flow'], errors='coerce')
    
    # Filtrar filas donde 'Free Cash Flow' no es NaN, vacío ni 0
    df_limpio = df[df['Free Cash Flow'].notna() & (df['Free Cash Flow'] != 0)]
    
    # Guardar el resultado
    output_path = os.path.join(output_dir, f"{ticker}_completo_arreglado.csv")
    df_limpio.to_csv(output_path, index=False)
    print(f"Archivo limpio guardado: {output_path}")

# Directorios de entrada y salida
input_dir = './Dataset_500_completo'  # Cambia esto a la ruta de tus archivos completos
output_dir = './datos_limpios'  # Carpeta para los archivos limpios

# Crear directorio de salida si no existe
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Obtener todos los archivos completos
archivos = [f for f in os.listdir(input_dir) if f.endswith('_completo.csv')]
tickers = [f.split('_')[0] for f in archivos]

# Procesar cada ticker
for ticker in tickers:
    try:
        limpiar_datos(ticker, input_dir, output_dir)
    except Exception as e:
        print(f"Error procesando {ticker}: {str(e)}")

print("Proceso completado. Archivos limpios guardados en:", output_dir)
# Out:
# Archivo limpio guardado: ./datos_limpios/NWSA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CF_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TSCO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AJG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GEN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LOW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HIG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LYV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/XOM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TEL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PODD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/XYL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EMR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SBUX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PEG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ITW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ADM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PSA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CMS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WBA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DOW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/O_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/COO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DTE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DHI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/POOL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FRT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/JKHY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/QCOM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/RF_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HPQ_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DPZ_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/VTRS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PPG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EXR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MMM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FOXA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PCAR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ATO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SCHW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MTD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DIS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/STT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/RMD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PNW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LDOS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LMT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BAC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GEHC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/IT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AEP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PLTR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NKE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GEV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CPB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EQIX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/APO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AMZN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/COP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GPN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MPC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/APH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/URI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CHTR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GWW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PANW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SWKS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DVA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TPL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/COST_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DOV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NVR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TPR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BF-B_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ADBE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TRGP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NCLH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ZTS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LNT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LKQ_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SBAC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/VRSN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FDS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BDX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ELV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CTSH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MOH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TSLA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SYY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BALL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/OKE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/IRM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CHRW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DELL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HBAN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HUM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TRMB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AIG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PHM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ALB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TRV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/UPS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CVX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KIM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/JNJ_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/V_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ED_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DGX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ON_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/VICI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FANG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NOC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PSX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MU_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/UAL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SWK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GRMN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CBRE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/OXY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KEYS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PFG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WDC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WRB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MTB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TER_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HRL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FTV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SYF_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/IR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LEN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PPL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/STX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EXPD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CPRT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LYB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PAYX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NRG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ECL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PWR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SYK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ABBV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MCK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/VMC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/APD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NDAQ_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GOOGL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WSM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BMY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/INCY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CMG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DOC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/META_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/VST_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GILD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FCX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ZBRA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AON_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PNC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MSI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SPGI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KMX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/RSG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CRM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WAT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MKTX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ROL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HPE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DUK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/XEL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TYL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HCA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ROK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FITB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/RVTY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EQR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CRWD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WMB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MRK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ALLE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MNST_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/D_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SPG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FSLR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/JBHT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/C_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/VTR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DXCM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TXN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GIS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CVS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AZO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SOLV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AVGO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GPC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FIS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NSC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CHD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HON_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ACGL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HSIC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SRE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CMCSA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ETN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MDT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/UNH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NEE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BEN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/UHS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EXPE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KHC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MGM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/RL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TMO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CCL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WDAY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AVY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LRCX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EQT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CTRA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MKC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/UNP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NOW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GDDY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AMCR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WST_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EVRG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GLW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BIIB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/IDXX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EBAY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MRNA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FDX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ORLY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EIX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PKG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CTVA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/RTX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TMUS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WELL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AEE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/INTC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NDSN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DLTR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LVS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AMT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CAH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/REG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/JNPR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CRL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DVN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TROW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KDP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WTW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AMAT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MAS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LLY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ADSK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PEP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ROST_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ORCL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ALL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/IEX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TDY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MCO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TECH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CBOE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MSFT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MET_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BRO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CCI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DRI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/IPG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/IFF_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CDW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DFS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PLD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SHW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ROP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MSCI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ENPH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AKAM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MCHP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GOOG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LULU_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EXE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NUE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PAYC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SMCI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ALGN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SJM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AOS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PRU_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ICE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/USB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LHX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DAL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ABNB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CAT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MMC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HLT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ULTA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AMGN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ERIE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/STZ_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HOLX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ISRG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KMB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LUV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AXP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CME_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MAR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TFC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MTCH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/APA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/IVZ_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TXT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ESS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AMP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HII_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/STE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CNC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DECK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EXC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NXPI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CLX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AVB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CPT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/JBL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TDG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EOG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/A_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PGR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ES_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/YUM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TKO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/APTV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/F_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FTNT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/COF_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ETR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/JCI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/JPM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/VLTO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FFIV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/VRTX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ARE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HSY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WYNN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AIZ_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/L_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/OTIS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/VZ_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/VRSK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/K_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CSCO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BRK-B_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HST_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ADI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/IQV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ANET_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AXON_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NFLX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BLK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/RJF_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TSN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NTRS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BAX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BKR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DAY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FAST_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NTAP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TGT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/IBM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CTAS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GNRC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EMN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/OMC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KVUE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/T_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WEC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/UBER_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PTC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BBY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AAPL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DHR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MCD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TAP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ZBH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CSX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CSGP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CFG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/IP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KEY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AES_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BLDR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/INTU_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KLAC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DLR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AME_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PFE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MHK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DASH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TJX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PCG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BKNG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/STLD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CAG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ABT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CDNS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FOX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CZR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HAS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FICO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BXP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TTWO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EFX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CINF_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ODFL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WFC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NWS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SLB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EPAM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/J_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PYPL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CEG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BSX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LIN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SNPS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WBD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/UDR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HES_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PARA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MAA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AWK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ANSS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LII_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MPWR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PNR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MOS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HWM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HUBB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HAL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MDLZ_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WAB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CNP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/VLO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CPAY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AMD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/INVH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KMI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ADP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CMI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/RCL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WMT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SNA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KKR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NEM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/COR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ACN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NVDA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/REGN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CARR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MLM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AFL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EG_completo_arreglado.csv
# Proceso completado. Archivos limpios guardados en: ./datos_limpios

# %%
import pandas as pd
import os
import numpy as np

def encontrar_columnas_comunes(directorio, archivo_referencia):
    """
    Encuentra las columnas comunes entre todos los archivos CSV en el directorio
    basándose en un archivo de referencia.
    """
    # Leer las columnas del archivo de referencia
    referencia = pd.read_csv(os.path.join(directorio, archivo_referencia), nrows=0)
    columnas_comunes = set(referencia.columns)
    
    # Listar todos los archivos CSV en el directorio
    archivos = [f for f in os.listdir(directorio) if f.endswith('.csv')]
    
    # Encontrar la intersección de columnas entre todos los archivos
    for archivo in archivos:
        if archivo == archivo_referencia:
            continue
            
        try:
            df_temp = pd.read_csv(os.path.join(directorio, archivo), nrows=0)
            columnas_comunes = columnas_comunes.intersection(set(df_temp.columns))
        except Exception as e:
            print(f"Error leyendo {archivo}: {str(e)}")
            continue
    
    print(f"Se encontraron {len(columnas_comunes)} columnas comunes")
    return list(columnas_comunes)

# %%
def normalizar_dataset(directorio, columnas_comunes, directorio_salida=None):
    """
    Normaliza todos los archivos CSV en el directorio manteniendo solo las columnas comunes.
    """
    if directorio_salida is None:
        directorio_salida = directorio
    
    # Crear directorio de salida si no existe
    if not os.path.exists(directorio_salida):
        os.makedirs(directorio_salida)
    
    # Listar todos los archivos CSV en el directorio
    archivos = [f for f in os.listdir(directorio) if f.endswith('.csv')]
    
    for archivo in archivos:
        try:
            # Leer el archivo
            df = pd.read_csv(os.path.join(directorio, archivo))
            
            # Mantener solo las columnas comunes
            columnas_existentes = [col for col in columnas_comunes if col in df.columns]
            df_normalizado = df[columnas_existentes]
            
            # Guardar el archivo normalizado
            ruta_salida = os.path.join(directorio_salida, archivo)
            df_normalizado.to_csv(ruta_salida, index=False)
            
            print(f"Archivo {archivo} normalizado. Se mantuvieron {len(columnas_existentes)} columnas.")
            
        except Exception as e:
            print(f"Error procesando {archivo}: {str(e)}")
            continue

# %%
# Configuración
directorio = "./datos_limpios"  # Cambia esto por tu directorio
archivo_referencia = "BX_completo_arreglado.csv"  # Archivo con las 111 columnas
directorio_salida = "./datos_normalizados"  # Directorio para archivos normalizados

# Encontrar columnas comunes
columnas_comunes = encontrar_columnas_comunes(directorio, archivo_referencia)

# Normalizar dataset
normalizar_dataset(directorio, columnas_comunes, directorio_salida)

# Verificar que todos los archivos tengan las mismas columnas
def verificar_consistencia(directorio):
    """
    Verifica que todos los archivos en el directorio tengan las mismas columnas.
    """
    archivos = [f for f in os.listdir(directorio) if f.endswith('.csv')]
    columnas_base = None
    
    for archivo in archivos:
        df_temp = pd.read_csv(os.path.join(directorio, archivo), nrows=0)
        
        if columnas_base is None:
            columnas_base = set(df_temp.columns)
            print(f"Columnas base ({len(columnas_base)}): {sorted(columnas_base)}")
        else:
            columnas_actual = set(df_temp.columns)
            if columnas_base != columnas_actual:
                print(f"Advertencia: {archivo} tiene columnas diferentes")
                print(f"Faltantes: {columnas_base - columnas_actual}")
                print(f"Adicionales: {columnas_actual - columnas_base}")
    
    print("Verificación de consistencia completada")

# Verificar consistencia
verificar_consistencia(directorio_salida)
# Out:
# Se encontraron 48 columnas comunes
# Archivo GOOGL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo SRE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo STT_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PGR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo LEN_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TDY_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo VRSN_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo IVZ_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MTCH_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo SYK_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo SW_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo NXPI_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo RTX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo EXC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CARR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ADBE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CCL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo LYV_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo IT_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DLR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo POOL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo IBM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo FTV_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo VTR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo NVDA_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo EQR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo STLD_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo NUE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AEE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PNC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MMM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CPT_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PEG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo SLB_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo WY_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo COST_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo LULU_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo UNH_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo SCHW_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo APA_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CI_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo INTU_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo BXP_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo SYF_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo NKE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MPWR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CSX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo FITB_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo UDR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo BBY_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CRL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo UHS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MTB_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TRV_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo BMY_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TECH_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo KMX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo NRG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo BAX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo WRB_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DASH_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PCAR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ATO_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MAA_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ACGL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo GM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CAT_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TMO_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo JBHT_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo UBER_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo JCI_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo APH_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DOW_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo BKNG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo STZ_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AVY_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo IP_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CPRT_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo HSIC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CHRW_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo HD_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ROK_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MRNA_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DHR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AMD_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PRU_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo EMN_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo HBAN_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DGX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PSA_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo SBAC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo KO_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo NCLH_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo GD_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ANSS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MMC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo WDC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo SPGI_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo APO_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AAPL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo NWS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo WYNN_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo KEY_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo WAT_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo LOW_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ROL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TRMB_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ADSK_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PPG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MSI_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CNP_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo LHX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PFE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo IQV_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PTC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo UAL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo T_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PAYX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AIG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ENPH_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo FIS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CBRE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo VICI_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo OTIS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo VST_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo WTW_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TROW_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ELV_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo KVUE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MPC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo KLAC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo GRMN_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TPL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo HIG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo LDOS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo BX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo SMCI_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AJG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo BRK-B_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo APD_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo HPE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CF_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AMCR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo COO_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo EW_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo SBUX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ZBRA_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo BR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AWK_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ROST_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo WMT_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MDT_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo RCL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AFL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo NTRS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo BRO_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PPL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo WST_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CBOE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo GE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MU_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TFC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo GIS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo INVH_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo LVS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo NOC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo OXY_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ERIE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo BALL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo IFF_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo NDSN_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TXN_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PYPL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo RVTY_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo RL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo GEHC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ULTA_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CMCSA_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AME_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo SOLV_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CCI_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo RF_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DOV_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo HWM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo KEYS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DD_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo VRSK_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo LLY_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PODD_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo GL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AOS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo LH_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CSCO_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TGT_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo XEL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo HII_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo EQT_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CTSH_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo EXE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo EQIX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo IR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo HAL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CRM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TT_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CB_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo GWW_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo STX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo HOLX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ES_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo SWKS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo FANG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MCHP_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ZTS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo KHC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AVGO_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo IPG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CHD_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo FFIV_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo LII_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ETN_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DAL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CMS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo V_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ADP_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo GEV_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo LKQ_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ANET_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ISRG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo JKHY_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo BLK_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TRGP_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CINF_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DTE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo GILD_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MTD_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo LUV_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo OKE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ORLY_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo USB_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MOS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo BSX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TEL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo COF_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ABBV_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ON_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PFG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TSN_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo HLT_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo VLO_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo LIN_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo J_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo NSC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CVX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo WBA_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PSX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo XOM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AXON_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo KMB_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PEP_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo FI_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo BKR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo FDX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo SPG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo HES_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo VZ_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo FTNT_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CME_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo FOXA_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DECK_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo META_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo WELL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo COP_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PLTR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo BDX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MCD_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo GPC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo INCY_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CSGP_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo BG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo EPAM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo HON_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PANW_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ACN_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DVA_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo JNPR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo NWSA_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo HUM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo IEX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo WEC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AKAM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MGM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AMGN_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo QCOM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DELL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DPZ_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo GPN_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CNC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo REGN_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AMP_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MOH_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo RSG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CEG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo FSLR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DOC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ETR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CHTR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo EVRG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo D_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo RJF_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AXP_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo BF-B_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo FOX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo EXPD_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo GEN_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TMUS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo LW_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo NEE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo NTAP_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo IRM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo GS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TAP_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo KR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ALLE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo FRT_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DLTR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo FAST_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AZO_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo VMC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo VRTX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo EL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PWR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo HAS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo HUBB_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TYL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo C_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CAG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PH_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PNW_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo HCA_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DAY_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MNST_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo LRCX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MLM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo RMD_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo WM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ABT_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo SWK_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CLX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PARA_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo XYL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ORCL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo SJM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo HRL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DXCM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AIZ_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo IDXX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MAR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TDG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo WMB_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo SNPS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo EA_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ESS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo LYB_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo LNT_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ABNB_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo KDP_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AMT_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo URI_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PKG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CDW_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo VLTO_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo COR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AVB_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MRK_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo BLDR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DHI_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CTVA_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ROP_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MSCI_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ZBH_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo JBL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo BEN_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo WAB_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TTWO_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TER_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TXT_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo UNP_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo LMT_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo HSY_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MKC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MAS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PHM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CMG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CDNS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DVN_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MO_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AEP_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo APTV_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo GNRC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TJX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MCK_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PLD_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo NFLX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo REG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ODFL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ECL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo NI_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo SO_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo JNJ_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo EOG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TSLA_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ALL_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo SYY_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo GDDY_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo EBAY_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo EG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo EMR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ADI_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo YUM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PAYC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo JPM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo O_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MSFT_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo WBD_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo FCX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo EXPE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo HST_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ITW_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo WFC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DIS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ED_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo GLW_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo EXR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo BA_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo VTRS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo SHW_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DUK_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CTAS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo BK_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo INTC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo STE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MKTX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo WDAY_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CFG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PCG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo NEM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CTRA_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo GOOG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PNR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo F_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CPAY_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AMAT_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CMI_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MA_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo L_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AON_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CAH_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo PG_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo NOW_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo FE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo UPS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DFS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo OMC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MET_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CRWD_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo NVR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo KIM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MHK_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo EIX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ALB_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo SNA_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MCO_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo DRI_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo HPQ_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo FICO_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ALGN_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo KKR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo BAC_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ICE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TSCO_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CPB_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo WSM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo EFX_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CZR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AES_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ARE_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo A_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo AMZN_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TKO_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo CVS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo TPR_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo K_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo MDLZ_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo BIIB_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo FDS_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo ADM_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo KMI_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Archivo NDAQ_completo_arreglado.csv normalizado. Se mantuvieron 48 columnas.
# Columnas base (48): ['Basic Average Shares', 'Basic EPS', 'Beginning Cash Position', 'Capital Stock', 'Cash And Cash Equivalents', 'Changes In Cash', 'Close', 'Common Stock', 'Common Stock Equity', 'Date', 'Diluted Average Shares', 'Diluted EPS', 'Diluted NI Availto Com Stockholders', 'End Cash Position', 'Financing Cash Flow', 'Free Cash Flow', 'High', 'Invested Capital', 'Investing Cash Flow', 'Long Term Debt And Capital Lease Obligation', 'Low', 'Net Income', 'Net Income Common Stockholders', 'Net Income Continuous Operations', 'Net Income From Continuing And Discontinued Operation', 'Net Income From Continuing Operation Net Minority Interest', 'Net Income From Continuing Operations', 'Net Income Including Noncontrolling Interests', 'Net Tangible Assets', 'Normalized Income', 'Open', 'Operating Cash Flow', 'Operating Revenue', 'Ordinary Shares Number', 'Pretax Income', 'Share Issued', 'Stockholders Equity', 'Tangible Book Value', 'Tax Effect Of Unusual Items', 'Tax Rate For Calcs', 'Total Assets', 'Total Capitalization', 'Total Debt', 'Total Equity Gross Minority Interest', 'Total Liabilities Net Minority Interest', 'Total Revenue', 'Volume', 'sectorKey']
# Verificación de consistencia completada

# %%
 # !pip install TA-Lib
# Out:
# Collecting TA-Lib
#   Downloading ta_lib-0.6.7-cp311-cp311-macosx_14_0_arm64.whl.metadata (24 kB)
# Collecting build (from TA-Lib)
#   Downloading build-1.3.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting cython (from TA-Lib)
#   Downloading cython-3.1.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.7 kB)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from TA-Lib) (1.26.4)
# Requirement already satisfied: packaging>=19.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from build->TA-Lib) (24.2)
# Collecting pyproject_hooks (from build->TA-Lib)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Downloading ta_lib-0.6.7-cp311-cp311-macosx_14_0_arm64.whl (999 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 999.9/999.9 kB 15.1 MB/s  0:00:00
# Downloading build-1.3.0-py3-none-any.whl (23 kB)
# Downloading cython-3.1.3-cp311-cp311-macosx_11_0_arm64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 24.6 MB/s  0:00:00
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Installing collected packages: pyproject_hooks, cython, build, TA-Lib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [TA-Lib]2m3/4 [TA-Lib]
# Successfully installed TA-Lib-0.6.7 build-1.3.0 cython-3.1.3 pyproject_hooks-1.2.0

# %%
import pandas as pd
import glob

def obtener_sectores_unicos(path_pattern="data/*.csv", col_sector="sectorKey"):
    """
    Lee múltiples CSV y devuelve una lista de todos los sectores únicos.
    
    Args:
        path_pattern (str): patrón de búsqueda para archivos CSV (ej: 'data/*.csv')
        col_sector (str): nombre de la columna que contiene el sector
    
    Returns:
        list: lista de sectores únicos encontrados en todos los archivos
    """
    sectores = set()
    
    # Buscar todos los CSV en la ruta indicada
    for file in glob.glob(path_pattern):
        df = pd.read_csv(file)
        if col_sector in df.columns:
            sectores.update(df[col_sector].dropna().unique())
    
    return sorted(list(sectores))

# Ejemplo de uso
sectores_totales = obtener_sectores_unicos("./datos_normalizados/*.csv", col_sector="sectorKey")
print("Sectores encontrados:", sectores_totales)
# Out:
# Sectores encontrados: ['basic-materials', 'communication-services', 'consumer-cyclical', 'consumer-defensive', 'energy', 'financial-services', 'healthcare', 'industrials', 'real-estate', 'technology', 'utilities']

# %%
len(sectores_totales)
# Out:
# 11

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
import joblib
import talib as ta


def calculate_technical_indicators(df):
    """Calcula 48 indicadores técnicos y agrega datos financieros"""
    # Precios
    open_price = df['Open'].values
    high = df['High'].values
    low = df['Low'].values
    close = df['Close'].values
    volume = df['Volume'].values
    
    features = {}
    
    # ===== INDICADORES TÉCNICOS (48 features) =====
    
    # Medias móviles (8 features)
    features['SMA_5'] = ta.SMA(close, timeperiod=5)
    features['SMA_10'] = ta.SMA(close, timeperiod=10)
    features['SMA_20'] = ta.SMA(close, timeperiod=20)
    features['SMA_50'] = ta.SMA(close, timeperiod=50)
    features['EMA_5'] = ta.EMA(close, timeperiod=5)
    features['EMA_10'] = ta.EMA(close, timeperiod=10)
    features['EMA_20'] = ta.EMA(close, timeperiod=20)
    features['EMA_50'] = ta.EMA(close, timeperiod=50)
    
    # Osciladores (12 features)
    features['RSI'] = ta.RSI(close)
    features['STOCH_K'], features['STOCH_D'] = ta.STOCH(high, low, close)
    features['MACD'], features['MACD_Signal'], features['MACD_Hist'] = ta.MACD(close)
    features['ADX'] = ta.ADX(high, low, close)
    features['CCI'] = ta.CCI(high, low, close)
    features['WILLR'] = ta.WILLR(high, low, close)
    features['ULTOSC'] = ta.ULTOSC(high, low, close)
    features['ROC'] = ta.ROC(close)
    
    # Volatilidad (6 features)
    features['ATR'] = ta.ATR(high, low, close)
    features['NATR'] = ta.NATR(high, low, close)
    features['TRANGE'] = ta.TRANGE(high, low, close)
    features['BB_Upper'], features['BB_Middle'], features['BB_Lower'] = ta.BBANDS(close)
    
    # Volumen (5 features)
    # features['OBV'] = ta.OBV(close, volume)
    # features['AD'] = ta.AD(high, low, close, volume)
    # features['ADOSC'] = ta.ADOSC(high, low, close, volume)
    # features['MFI'] = ta.MFI(high, low, close, volume)
    
    # Momentum (8 features)
    features['MOM'] = ta.MOM(close)
    features['PPO'] = ta.PPO(close)
    features['APO'] = ta.APO(close)
    features['AROON_Up'], features['AROON_Down'] = ta.AROON(high, low)
    features['AROONOSC'] = ta.AROONOSC(high, low)
    features['BOP'] = ta.BOP(open_price, high, low, close)
    
    # Precios relativos (9 features)
    features['Price_Change'] = close / np.roll(close, 1) - 1
    features['High_Low_Ratio'] = high / low
    features['Close_Open_Ratio'] = close / open_price
    # features['Volume_Change'] = volume / np.roll(volume, 1) - 1
    
    # ===== DATOS FINANCIeros DEL CSV (46 features adicionales) =====
    
    # Flujo de caja y liquidez
    features['Free_Cash_Flow'] = df['Free Cash Flow']
    features['Operating_Cash_Flow'] = df['Operating Cash Flow']
    features['Investing_Cash_Flow'] = df['Investing Cash Flow']
    features['Financing_Cash_Flow'] = df['Financing Cash Flow']
    features['Beginning_Cash_Position'] = df['Beginning Cash Position']
    features['End_Cash_Position'] = df['End Cash Position']
    features['Changes_In_Cash'] = df['Changes In Cash']
    features['Cash_And_Cash_Equivalents'] = df['Cash And Cash Equivalents']
    
    # Rentabilidad
    features['Net_Income'] = df['Net Income']
    features['Pretax_Income'] = df['Pretax Income']
    features['Total_Revenue'] = df['Total Revenue']
    features['Operating_Revenue'] = df['Operating Revenue']
    features['Normalized_Income'] = df['Normalized Income']
    features['Net_Income_Common_Stockholders'] = df['Net Income Common Stockholders']
    features['Net_Income_From_Continuing_Operations'] = df['Net Income From Continuing Operations']
    features['Net_Income_From_Continuing_And_Discontinued_Operation'] = df['Net Income From Continuing And Discontinued Operation']
    features['Net_Income_Including_Noncontrolling_Interests'] = df['Net Income Including Noncontrolling Interests']
    features['Net_Income_Continuous_Operations'] = df['Net Income Continuous Operations']
    features['Diluted_NI_Availto_Com_Stockholders'] = df['Diluted NI Availto Com Stockholders']
    features['Net_Income_From_Continuing_Operation_Net_Minority_Interest'] = df['Net Income From Continuing Operation Net Minority Interest']
    
    # Por acción
    features['Basic_EPS'] = df['Basic EPS']
    features['Diluted_EPS'] = df['Diluted EPS']
    
    # Acciones
    features['Diluted_Average_Shares'] = df['Diluted Average Shares']
    features['Basic_Average_Shares'] = df['Basic Average Shares']
    features['Share_Issued'] = df['Share Issued']
    features['Ordinary_Shares_Number'] = df['Ordinary Shares Number']
    features['Capital_Stock'] = df['Capital Stock']
    features['Common_Stock'] = df['Common Stock']
    
    # Balance general
    features['Total_Assets'] = df['Total Assets']
    features['Total_Liabilities_Net_Minority_Interest'] = df['Total Liabilities Net Minority Interest']
    features['Total_Equity_Gross_Minority_Interest'] = df['Total Equity Gross Minority Interest']
    features['Common_Stock_Equity'] = df['Common Stock Equity']
    features['Stockholders_Equity'] = df['Stockholders Equity']
    features['Total_Capitalization'] = df['Total Capitalization']
    features['Invested_Capital'] = df['Invested Capital']
    features['Net_Tangible_Assets'] = df['Net Tangible Assets']
    features['Tangible_Book_Value'] = df['Tangible Book Value']
    
    # Deuda
    features['Total_Debt'] = df['Total Debt']
    features['Long_Term_Debt_And_Capital_Lease_Obligation'] = df['Long Term Debt And Capital Lease Obligation']
    
    # Ratios financieros
    features['Tax_Rate_For_Calcs'] = df['Tax Rate For Calcs']
    features['Tax_Effect_Of_Unusual_Items'] = df['Tax Effect Of Unusual Items']
    features['Close'] = df['Close']
    features['Date'] = df['Date']
    
    # Sector (convertir a numérico si es necesario)
    # if 'sectorKey' in df.columns:
    #     # One-hot encoding para sector
    #     sector_dummies = pd.get_dummies(df['sectorKey'], prefix='Sector')
    #     for col in sector_dummies.columns:
    #         features[col] = sector_dummies[col]
    if 'sectorKey' in df.columns:
        # Generar one-hot encoding SOLO de los sectores presentes en este df
        sector_dummies = pd.get_dummies(df['sectorKey'], prefix='Sector')

        # Crear todas las columnas esperadas en base a sectores_totales
        expected_cols = [f"Sector_{s}" for s in sectores_totales]

        # Reindexar para incluir todos los sectores, rellenando con 0 donde falten
        sector_dummies = sector_dummies.reindex(columns=expected_cols, fill_value=0)

        # Convertir booleanos a enteros (0 o 1)
        sector_dummies = sector_dummies.astype(int)

        # Agregar cada columna dummy al diccionario de features
        for col in sector_dummies.columns:
            features[col] = sector_dummies[col]  
    
    # Convertir a DataFrame
    features_df = pd.DataFrame(features, index=df.index)
    
    # Eliminar columnas que puedan tener todos valores NaN
    features_df = features_df.dropna(axis=1, how='all')
    
    # Llenar valores NaN restantes con 0 o método apropiado
    features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
    
    return features_df

# %%
def create_target_variable(df, horizon):
    """Crea la variable objetivo: % cambio en los próximos 3 meses (63 días trading)"""
    # Asegurarse de que los datos están ordenados por fecha
    df = df.sort_index()
    
    # Calcular precio futuro (3 meses después)
    future_prices = df['Close'].shift(-horizon)
    current_prices = df['Close']
    
    # Calcular porcentaje de cambio
    target = ((future_prices - current_prices) / current_prices) * 100
    
    # Crear DataFrame con target
    target_df = pd.DataFrame({
        'Target_3M_Return': target,
        'Target_Direction': np.where(target > 0, 1, 0)  # 1: subida, 0: bajada
    }, index=df.index)
    df_with_target = df.join(target_df, how='left')
    
    # Eliminar valores donde no hay futuro disponible
    df_with_target = df_with_target.dropna()
    
    return df_with_target

# %%
def data_augmentation_dataset(directorio, directorio_salida=None):
    """
    Normaliza todos los archivos CSV en el directorio manteniendo solo las columnas comunes.
    """
    if directorio_salida is None:
        directorio_salida = directorio
    
    # Crear directorio de salida si no existe
    if not os.path.exists(directorio_salida):
        os.makedirs(directorio_salida)
    
    # Listar todos los archivos CSV en el directorio
    archivos = [f for f in os.listdir(directorio) if f.endswith('.csv')]
    # archivos = ["A_completo_arreglado.csv"]
    
    for archivo in archivos:
        try:
            # Leer el archivo
            df = pd.read_csv(os.path.join(directorio, archivo))
            df_2 = calculate_technical_indicators(df=df)
            df_3 = create_target_variable(df=df_2, horizon= 60)

            # Guardar el archivo normalizado
            ruta_salida = os.path.join(directorio_salida, archivo)
            df_3.to_csv(ruta_salida, index=False)
            
        except Exception as e:
            print(f"Error procesando {archivo}: {str(e)}")
            continue

# %%
import os
import shutil

# Configuración
directorio = "./datos_normalizados"  # Cambia esto por tu directorio
directorio_salida = "./data_augmentation"  # Directorio para archivos normalizados

# Encontrar columnas comunes
data_augmentation_dataset(directorio, directorio_salida)
# Out:
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
# ...
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)

# %%
def create_target_variable_v2(df, horizon):
    """Crea la variable objetivo: % cambio en los próximos 3 meses (63 días trading)"""
    # Asegurarse de que los datos están ordenados por fecha
    df = df.sort_index()
    
    # Calcular precio futuro (3 meses después)
    future_prices = df['Close'].shift(-horizon)
    current_prices = df['Close']
    
    # Calcular porcentaje de cambio
    target = ((future_prices - current_prices) / current_prices) * 100
    
    # Crear DataFrame con target
    target_df = pd.DataFrame({
        'Target_3M_Return': target,
        'Target_Direction': np.where(target > 0, 1, 0)  # 1: subida, 0: bajada
    }, index=df.index)
    df_with_target = df.join(target_df, how='left')
    
    # Eliminar valores donde no hay futuro disponible
    # df_with_target = df_with_target.dropna()
    
    return df_with_target

# %%
def data_augmentation_dataset_with_unknow_values(directorio, directorio_salida=None):
    """
    Normaliza todos los archivos CSV en el directorio manteniendo solo las columnas comunes.
    """
    if directorio_salida is None:
        directorio_salida = directorio
    
    # Crear directorio de salida si no existe
    if not os.path.exists(directorio_salida):
        os.makedirs(directorio_salida)
    
    # Listar todos los archivos CSV en el directorio
    archivos = [f for f in os.listdir(directorio) if f.endswith('.csv')]
    # archivos = ["A_completo_arreglado.csv"]
    
    for archivo in archivos:
        try:
            # Leer el archivo
            df = pd.read_csv(os.path.join(directorio, archivo))
            df_2 = calculate_technical_indicators(df=df)
            df_3 = create_target_variable_v2(df=df_2, horizon= 60)

            # Guardar el archivo normalizado
            ruta_salida = os.path.join(directorio_salida, archivo)
            df_3.to_csv(ruta_salida, index=False)
            
        except Exception as e:
            print(f"Error procesando {archivo}: {str(e)}")
            continue

# %%
import os
import shutil

# Configuración
directorio = "./datos_normalizados"  # Cambia esto por tu directorio
directorio_salida = "./data_augmentation_unknow_values"  # Directorio para archivos normalizados

# Encontrar columnas comunes
data_augmentation_dataset_with_unknow_values(directorio, directorio_salida)
# Out:
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
# ...
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_48398/1441644667.py:157: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
